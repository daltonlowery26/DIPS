# %% [markdown]
# ### xgboost model to predict mean player outcomes
# used in conjunction with nn algs to determine mean wrc for player. Three diffrent models based on available data then combinded to create an xgb predection.

# %%
import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt
import sys
function_dir = 'C:/Users/dalto/OneDrive/Pictures/Documents/Projects/MLB Season Model/tools'
sys.path.append(function_dir)

os.chdir('C:/Users/dalto/OneDrive/Pictures/Documents/Projects/MLB Season Model/')

# %%
# import data
data_02_24 = pd.read_csv('./data/cleaned/data_02_24.csv')
data_15_24 = pd.read_csv('./data/cleaned/data_15_24.csv')
df = data_15_24.drop(columns=['Unnamed: 0'])
df = df.dropna()

# %% [markdown]
# #### normalize data

# %% [markdown]
# apply z scores

# %%
from tools.zscore import normalize
z_score_df = normalize(df)

# %% [markdown]
# ### xgboost model

# %%
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.decomposition import PCA

# %% [markdown]
# make wrc+ value the next year

# %%
# remove 2024 to train model bc we do not know the following year
train_z = z_score_df[z_score_df['Season'] < 2024].copy()
train_z['next_wrc+'] = np.nan # empty col


for idx in train_z.index:
    # retrive name, season
    name = train_z.loc[idx, 'Name']
    season = train_z.loc[idx, 'Season']
    # full df
    next_year_noscale = df[(df['Name'] == name) & (df['Season'] == season + 1)]
    next_year_scaled = z_score_df[(z_score_df['Name'] == name) & (z_score_df['Season'] == season + 1)]

    # add to df
    if not next_year_noscale.empty:
        train_z.loc[idx, 'next_wrc+'] = next_year_noscale['wRC+'].iloc[0]
        train_z.loc[idx, 'next_pa'] = next_year_noscale['PA'].iloc[0] # need for later anaylsis

# remove rows of nas | players retired etc.
train_z = train_z.dropna(subset=['next_wrc+'])

# display
train_z.head()
# Out:
#             Name  Season         PA        Age         BB%          K%  \
# 0  aaron altherr    2015  83.803386  88.938011  106.696917  109.230499
# 1  aaron altherr    2016  87.484455  91.264979  105.841726  115.765286
# 2  aaron altherr    2017  97.459324  94.128509   97.111622  106.258881
# 3  aaron altherr    2018  90.564977  97.266110  112.293740  115.814899
# 5    aaron hicks    2015  96.403928  91.489408  102.878580   95.051399
#
#         BABIP        wRC+         BsR         Off  ...       xwoba  \
# 0  100.160880  108.453531  102.964885  101.884763  ...   99.781669
# 1   96.704929   87.103359   98.833475   90.315507  ...   90.988686
# 2  106.542076  107.075414   95.409204  104.059124  ...  104.848414
# 3   87.369444   91.021666  101.857768   92.275804  ...   99.975513
# 5   96.266940   98.756712  101.035114   97.235810  ...  103.803587
#
#    sweet_spot_percent  barrel_batted_rate  hard_hit_percent  avg_best_speed  \
# 0          103.037868           93.362432        111.205981      109.356964
# 1           91.357501           91.456280         99.784109      100.990725
# 2           98.056612          109.330507        110.896987      113.596577
# 3           92.370925          106.899772        111.856531      112.750551
# 5          104.601736           93.621832         99.206091       97.688526
#
#    avg_hyper_speed  whiff_percent  swing_percent   next_wrc+  next_pa
# 0       109.841857     104.844345      88.081090   63.946339    227.0
# 1       100.214769     109.467380      93.025993  119.718295    412.0
# 2       113.237654     109.531036      95.095776   73.992787    285.0
# 3       112.410594     113.463612      95.637806  -22.663759     66.0
# 5        97.887723      96.722672      95.483790   63.755251    361.0
#
# [5 rows x 37 columns]

# %% [markdown]
# inject noise to next_pa
# <br>
# <small> I want to mimmic the accuracy of my projection model so that next_pa is not overweighted as a feature.

# %%
num_points = len(train_z['next_pa'])
noise = np.random.normal(loc=0, scale=75, size=num_points)  # corresponds to less than 0.8 std which is how much model misses on avg
train_z['next_pa'] = train_z['next_pa'] + noise
train_z['next_pa'] = train_z['next_pa'].clip(lower=10, upper=735)
train_z.head()
# Out:
#             Name  Season         PA        Age         BB%          K%  \
# 0  aaron altherr    2015  83.803386  88.938011  106.696917  109.230499
# 1  aaron altherr    2016  87.484455  91.264979  105.841726  115.765286
# 2  aaron altherr    2017  97.459324  94.128509   97.111622  106.258881
# 3  aaron altherr    2018  90.564977  97.266110  112.293740  115.814899
# 5    aaron hicks    2015  96.403928  91.489408  102.878580   95.051399
#
#         BABIP        wRC+         BsR         Off  ...       xwoba  \
# 0  100.160880  108.453531  102.964885  101.884763  ...   99.781669
# 1   96.704929   87.103359   98.833475   90.315507  ...   90.988686
# 2  106.542076  107.075414   95.409204  104.059124  ...  104.848414
# 3   87.369444   91.021666  101.857768   92.275804  ...   99.975513
# 5   96.266940   98.756712  101.035114   97.235810  ...  103.803587
#
#    sweet_spot_percent  barrel_batted_rate  hard_hit_percent  avg_best_speed  \
# 0          103.037868           93.362432        111.205981      109.356964
# 1           91.357501           91.456280         99.784109      100.990725
# 2           98.056612          109.330507        110.896987      113.596577
# 3           92.370925          106.899772        111.856531      112.750551
# 5          104.601736           93.621832         99.206091       97.688526
#
#    avg_hyper_speed  whiff_percent  swing_percent   next_wrc+     next_pa
# 0       109.841857     104.844345      88.081090   63.946339  135.086516
# 1       100.214769     109.467380      93.025993  119.718295  416.957093
# 2       113.237654     109.531036      95.095776   73.992787  302.457418
# 3       112.410594     113.463612      95.637806  -22.663759   10.000000
# 5        97.887723      96.722672      95.483790   63.755251  298.101218
#
# [5 rows x 37 columns]

# %% [markdown]
# intial selection of data before feature selection

# %%
X = train_z.drop(columns=['Name', 'woba', 'next_wrc+',
                           'player_id', 'pa', 'bb_percent', 'k_percent', 
                           'woba', 'BsR', 'Def', 'Season', 'swing_percent',
                             'Z-Contact%', 'O-Contact%', 'Age'])
Y = train_z['next_wrc+']
xtrain, xtest, ytrain, ytest = train_test_split(X, Y, test_size=0.1, random_state=26)

# %% [markdown]
# train test split

# %%
# Calculate correlation matrix
corr = train_z.corr(numeric_only=True)

# next_wrc+ corr
corr_with_wrc = corr['next_wrc+'].sort_values(ascending=False)

print(corr_with_wrc)
# Out:
# next_wrc+             1.000000
# next_pa               0.508940
# xwoba                 0.376033
# WAR                   0.375782
# pa                    0.362678
# PA                    0.362660
# Off                   0.357684
# maxEV                 0.329896
# wRC+                  0.325496
# avg_best_speed        0.322980
# avg_hyper_speed       0.318865
# woba                  0.317967
# HardHit%              0.303441
# hard_hit_percent      0.303233
# Barrel%               0.271182
# barrel_batted_rate    0.270838
# bb_percent            0.165065
# BB%                   0.165006
# Contact%              0.100363
# BABIP                 0.098767
# O-Contact%            0.094767
# sweet_spot_percent    0.090077
# Z-Contact%            0.082691
# Z-Swing%              0.042496
# Season                0.019937
# player_id             0.011886
# BsR                   0.001486
# Age                  -0.034218
# swing_percent        -0.084621
# Def                  -0.085469
# O-Swing%             -0.087708
# whiff_percent        -0.095947
# SwStr%               -0.112681
# K%                   -0.135894
# k_percent            -0.135964
# CSW%                 -0.178766
# Name: next_wrc+, dtype: float64

# %%
model = xgb.XGBRegressor(n_jobs=-1, n_estimators=50000, device = "cuda", eval_metric = ['mae', 'rmse'])

# %% [markdown]
# ##### hyper para tuning

# %% [markdown]
# random search to narrow space into grid search

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
rnd_search_params = {
    'learning_rate': np.linspace(0.05, 0.2, 4),          
    'max_leaves': np.linspace(1, 40, 20, dtype=int),     
    'min_child_weight': np.linspace(1, 20, 10),         
    'subsample': np.linspace(0.3, 0.9, 7),               
    'colsample_bytree': np.linspace(0.4, 1, 7),          
    'early_stopping_rounds': np.linspace(10, 100, 10, dtype=int),  
    'max_depth': np.linspace(0, 40, 20, dtype=int)       
}

rnd_searcher = RandomizedSearchCV(model, rnd_search_params, random_state=26, n_iter=100, cv=10, n_jobs=-1, verbose=4)
rnd_searcher.fit(xtrain, ytrain, eval_set=[(xtest, ytest)])
print(rnd_searcher.best_params_)
# Out:
# Fitting 10 folds for each of 100 candidates, totalling 1000 fits
# [0]	validation_0-mae:28.66243	validation_0-rmse:38.99779
# [1]	validation_0-mae:27.48156	validation_0-rmse:37.40987
# [2]	validation_0-mae:26.54955	validation_0-rmse:36.20258
# [3]	validation_0-mae:25.84982	validation_0-rmse:35.27134
# [4]	validation_0-mae:25.39488	validation_0-rmse:34.70673
# [5]	validation_0-mae:24.92056	validation_0-rmse:34.17802
# [6]	validation_0-mae:24.44904	validation_0-rmse:33.49748
# [7]	validation_0-mae:24.12782	validation_0-rmse:33.08911
# [8]	validation_0-mae:23.86508	validation_0-rmse:32.73377
# [9]	validation_0-mae:23.72167	validation_0-rmse:32.59329
# [10]	validation_0-mae:23.57711	validation_0-rmse:32.34944
# [11]	validation_0-mae:23.42350	validation_0-rmse:32.12233
# [12]	validation_0-mae:23.39640	validation_0-rmse:32.14865
# [13]	validation_0-mae:23.40633	validation_0-rmse:32.19631
# [14]	validation_0-mae:23.29783	validation_0-rmse:32.07913
# [15]	validation_0-mae:23.19697	validation_0-rmse:31.92094
# [16]	validation_0-mae:23.12400	validation_0-rmse:31.85658
# [17]	validation_0-mae:23.00465	validation_0-rmse:31.71660
# [18]	validation_0-mae:22.97860	validation_0-rmse:31.70626
# [19]	validation_0-mae:22.94598	validation_0-rmse:31.71664
# [20]	validation_0-mae:22.94863	validation_0-rmse:31.73402
# [21]	validation_0-mae:22.93398	validation_0-rmse:31.71114
# [22]	validation_0-mae:22.87710	validation_0-rmse:31.62592
# [23]	validation_0-mae:22.85390	validation_0-rmse:31.59346
# [24]	validation_0-mae:22.79179	validation_0-rmse:31.52237
# [25]	validation_0-mae:22.77315	validation_0-rmse:31.51087
# [26]	validation_0-mae:22.78555	validation_0-rmse:31.54095
# [27]	validation_0-mae:22.78202	validation_0-rmse:31.57697
# [28]	validation_0-mae:22.77247	validation_0-rmse:31.58954
# [29]	validation_0-mae:22.72983	validation_0-rmse:31.55026
# [30]	validation_0-mae:22.74797	validation_0-rmse:31.61159
# [31]	validation_0-mae:22.79028	validation_0-rmse:31.69645
# [32]	validation_0-mae:22.73304	validation_0-rmse:31.63775
# [33]	validation_0-mae:22.75014	validation_0-rmse:31.65704
# c:\Users\dalto\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [11:31:22] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\context.cc:196: XGBoost is not compiled with CUDA support.
#   warnings.warn(smsg, UserWarning)
# [34]	validation_0-mae:22.72319	validation_0-rmse:31.65904
# [35]	validation_0-mae:22.67723	validation_0-rmse:31.64248
# [36]	validation_0-mae:22.65123	validation_0-rmse:31.65550
# [37]	validation_0-mae:22.66980	validation_0-rmse:31.69516
# [38]	validation_0-mae:22.64998	validation_0-rmse:31.67791
# [39]	validation_0-mae:22.63553	validation_0-rmse:31.66275
# [40]	validation_0-mae:22.65116	validation_0-rmse:31.70171
# [41]	validation_0-mae:22.65464	validation_0-rmse:31.68195
# [42]	validation_0-mae:22.64442	validation_0-rmse:31.68065
# [43]	validation_0-mae:22.63584	validation_0-rmse:31.65925
# [44]	validation_0-mae:22.65722	validation_0-rmse:31.71848
# [45]	validation_0-mae:22.66292	validation_0-rmse:31.72664
# [46]	validation_0-mae:22.65113	validation_0-rmse:31.71513
# [47]	validation_0-mae:22.63993	validation_0-rmse:31.70613
# [48]	validation_0-mae:22.63390	validation_0-rmse:31.69563
# [49]	validation_0-mae:22.65586	validation_0-rmse:31.72249
# [50]	validation_0-mae:22.68229	validation_0-rmse:31.73162
# [51]	validation_0-mae:22.73658	validation_0-rmse:31.85041
# [52]	validation_0-mae:22.68814	validation_0-rmse:31.76429
# [53]	validation_0-mae:22.68339	validation_0-rmse:31.79052
# [54]	validation_0-mae:22.70697	validation_0-rmse:31.85526
# [55]	validation_0-mae:22.72592	validation_0-rmse:31.86684
# [56]	validation_0-mae:22.76282	validation_0-rmse:31.88532
# [57]	validation_0-mae:22.76755	validation_0-rmse:31.89988
# [58]	validation_0-mae:22.75751	validation_0-rmse:31.88927
# [59]	validation_0-mae:22.77563	validation_0-rmse:31.89850
# [60]	validation_0-mae:22.80249	validation_0-rmse:31.94582
# [61]	validation_0-mae:22.82819	validation_0-rmse:32.01686
# [62]	validation_0-mae:22.88597	validation_0-rmse:32.11479
# [63]	validation_0-mae:22.85303	validation_0-rmse:32.09235
# [64]	validation_0-mae:22.80266	validation_0-rmse:31.98036
# [65]	validation_0-mae:22.81169	validation_0-rmse:31.99799
# [66]	validation_0-mae:22.81407	validation_0-rmse:32.00347
# [67]	validation_0-mae:22.80926	validation_0-rmse:31.95922
# [68]	validation_0-mae:22.78570	validation_0-rmse:31.91833
# [69]	validation_0-mae:22.78166	validation_0-rmse:31.91384
# [70]	validation_0-mae:22.76066	validation_0-rmse:31.89641
# [71]	validation_0-mae:22.77428	validation_0-rmse:31.93704
# [72]	validation_0-mae:22.78226	validation_0-rmse:31.95453
# [73]	validation_0-mae:22.81671	validation_0-rmse:31.95789
# [74]	validation_0-mae:22.81252	validation_0-rmse:31.99594
# [75]	validation_0-mae:22.83268	validation_0-rmse:31.99780
# [76]	validation_0-mae:22.85540	validation_0-rmse:32.03571
# [77]	validation_0-mae:22.86464	validation_0-rmse:32.05525
# [78]	validation_0-mae:22.86360	validation_0-rmse:32.05231
# [79]	validation_0-mae:22.88577	validation_0-rmse:32.12876
# [80]	validation_0-mae:22.85736	validation_0-rmse:32.09642
# [81]	validation_0-mae:22.83530	validation_0-rmse:32.02762
# [82]	validation_0-mae:22.84753	validation_0-rmse:32.04461
# [83]	validation_0-mae:22.81556	validation_0-rmse:32.02929
# [84]	validation_0-mae:22.83062	validation_0-rmse:32.04582
# {'subsample': 0.5, 'min_child_weight': 11.555555555555555, 'max_leaves': 11, 'max_depth': 2, 'learning_rate': 0.15000000000000002, 'early_stopping_rounds': 60, 'colsample_bytree': 1.0}

# %% [markdown]
# grid search

# %%
from sklearn.model_selection import GridSearchCV
grid_search_params = {
    'learning_rate': [0.05, 0.1],   
    'max_leaves': [6, 7, 8],
    'min_child_weight': [9, 10, 11],      
    'subsample': [0.5, 0.6, 0.7],           
    'colsample_bytree':[0.6, 0.7, 0.8],     
    'early_stopping_rounds':[20, 30, 40],
    'max_depth': [2, 3, 4]
}

# %%
grid_searcher = GridSearchCV(model, grid_search_params, cv=5, n_jobs=-1, verbose=4)
grid_searcher.fit(xtrain, ytrain, eval_set=[(xtest, ytest)])
print(grid_searcher.best_params_)
# Out:
# Fitting 5 folds for each of 1458 candidates, totalling 7290 fits
# [0]	validation_0-mae:29.65288	validation_0-rmse:40.27951
# [1]	validation_0-mae:29.39919	validation_0-rmse:39.97869
# [2]	validation_0-mae:28.91211	validation_0-rmse:39.37433
# [3]	validation_0-mae:28.66381	validation_0-rmse:39.07793
# [4]	validation_0-mae:28.25598	validation_0-rmse:38.56082
# [5]	validation_0-mae:27.88988	validation_0-rmse:38.08409
# [6]	validation_0-mae:27.68573	validation_0-rmse:37.84371
# [7]	validation_0-mae:27.29231	validation_0-rmse:37.34174
# [8]	validation_0-mae:26.93588	validation_0-rmse:36.87526
# [9]	validation_0-mae:26.64556	validation_0-rmse:36.51078
# [10]	validation_0-mae:26.35889	validation_0-rmse:36.15430
# [11]	validation_0-mae:26.22523	validation_0-rmse:35.99561
# [12]	validation_0-mae:25.95176	validation_0-rmse:35.65493
# [13]	validation_0-mae:25.72912	validation_0-rmse:35.37978
# [14]	validation_0-mae:25.51529	validation_0-rmse:35.08341
# [15]	validation_0-mae:25.33217	validation_0-rmse:34.83077
# [16]	validation_0-mae:25.16566	validation_0-rmse:34.61640
# [17]	validation_0-mae:25.00536	validation_0-rmse:34.39763
# c:\Users\dalto\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [12:02:20] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\context.cc:196: XGBoost is not compiled with CUDA support.
#   warnings.warn(smsg, UserWarning)
# [18]	validation_0-mae:24.85184	validation_0-rmse:34.18068
# [19]	validation_0-mae:24.71344	validation_0-rmse:34.00281
# [20]	validation_0-mae:24.56411	validation_0-rmse:33.80531
# [21]	validation_0-mae:24.48364	validation_0-rmse:33.71789
# [22]	validation_0-mae:24.41581	validation_0-rmse:33.64924
# [23]	validation_0-mae:24.29213	validation_0-rmse:33.48594
# [24]	validation_0-mae:24.18185	validation_0-rmse:33.33546
# [25]	validation_0-mae:24.06777	validation_0-rmse:33.17224
# [26]	validation_0-mae:23.99330	validation_0-rmse:33.10427
# [27]	validation_0-mae:23.93522	validation_0-rmse:33.04330
# [28]	validation_0-mae:23.86085	validation_0-rmse:32.95141
# [29]	validation_0-mae:23.80868	validation_0-rmse:32.90115
# [30]	validation_0-mae:23.76167	validation_0-rmse:32.86823
# [31]	validation_0-mae:23.72485	validation_0-rmse:32.82925
# [32]	validation_0-mae:23.69473	validation_0-rmse:32.80407
# [33]	validation_0-mae:23.66015	validation_0-rmse:32.77283
# [34]	validation_0-mae:23.60516	validation_0-rmse:32.71200
# [35]	validation_0-mae:23.57628	validation_0-rmse:32.67866
# [36]	validation_0-mae:23.50670	validation_0-rmse:32.60099
# [37]	validation_0-mae:23.46565	validation_0-rmse:32.56627
# [38]	validation_0-mae:23.41121	validation_0-rmse:32.51260
# [39]	validation_0-mae:23.37391	validation_0-rmse:32.48337
# [40]	validation_0-mae:23.36187	validation_0-rmse:32.47974
# [41]	validation_0-mae:23.32098	validation_0-rmse:32.42645
# [42]	validation_0-mae:23.28915	validation_0-rmse:32.38247
# [43]	validation_0-mae:23.26760	validation_0-rmse:32.36985
# [44]	validation_0-mae:23.23737	validation_0-rmse:32.33978
# [45]	validation_0-mae:23.20374	validation_0-rmse:32.29536
# [46]	validation_0-mae:23.16533	validation_0-rmse:32.24699
# [47]	validation_0-mae:23.13270	validation_0-rmse:32.20298
# [48]	validation_0-mae:23.10384	validation_0-rmse:32.16858
# [49]	validation_0-mae:23.07753	validation_0-rmse:32.15877
# [50]	validation_0-mae:23.08092	validation_0-rmse:32.17438
# [51]	validation_0-mae:23.07437	validation_0-rmse:32.17819
# [52]	validation_0-mae:23.02499	validation_0-rmse:32.12804
# [53]	validation_0-mae:22.99448	validation_0-rmse:32.10028
# [54]	validation_0-mae:22.96284	validation_0-rmse:32.07666
# [55]	validation_0-mae:22.92805	validation_0-rmse:32.03456
# [56]	validation_0-mae:22.91106	validation_0-rmse:32.00546
# [57]	validation_0-mae:22.90478	validation_0-rmse:31.99322
# [58]	validation_0-mae:22.88655	validation_0-rmse:31.96995
# [59]	validation_0-mae:22.86263	validation_0-rmse:31.93060
# [60]	validation_0-mae:22.85071	validation_0-rmse:31.91856
# [61]	validation_0-mae:22.84638	validation_0-rmse:31.91222
# [62]	validation_0-mae:22.85248	validation_0-rmse:31.92214
# [63]	validation_0-mae:22.85240	validation_0-rmse:31.92070
# [64]	validation_0-mae:22.82911	validation_0-rmse:31.91102
# [65]	validation_0-mae:22.81562	validation_0-rmse:31.90543
# [66]	validation_0-mae:22.77728	validation_0-rmse:31.82789
# [67]	validation_0-mae:22.77362	validation_0-rmse:31.83415
# [68]	validation_0-mae:22.74681	validation_0-rmse:31.78342
# [69]	validation_0-mae:22.72632	validation_0-rmse:31.75914
# [70]	validation_0-mae:22.71056	validation_0-rmse:31.74955
# [71]	validation_0-mae:22.70298	validation_0-rmse:31.74545
# [72]	validation_0-mae:22.67783	validation_0-rmse:31.71464
# [73]	validation_0-mae:22.67843	validation_0-rmse:31.72540
# [74]	validation_0-mae:22.67636	validation_0-rmse:31.73703
# [75]	validation_0-mae:22.67185	validation_0-rmse:31.71623
# [76]	validation_0-mae:22.69140	validation_0-rmse:31.74464
# [77]	validation_0-mae:22.66856	validation_0-rmse:31.69964
# [78]	validation_0-mae:22.64740	validation_0-rmse:31.64436
# [79]	validation_0-mae:22.65846	validation_0-rmse:31.67929
# [80]	validation_0-mae:22.67159	validation_0-rmse:31.68780
# [81]	validation_0-mae:22.65430	validation_0-rmse:31.66065
# [82]	validation_0-mae:22.64590	validation_0-rmse:31.65441
# [83]	validation_0-mae:22.65518	validation_0-rmse:31.68264
# [84]	validation_0-mae:22.65256	validation_0-rmse:31.68426
# [85]	validation_0-mae:22.65382	validation_0-rmse:31.69458
# [86]	validation_0-mae:22.66032	validation_0-rmse:31.71631
# [87]	validation_0-mae:22.64177	validation_0-rmse:31.66462
# [88]	validation_0-mae:22.64467	validation_0-rmse:31.66966
# [89]	validation_0-mae:22.65633	validation_0-rmse:31.68598
# [90]	validation_0-mae:22.66770	validation_0-rmse:31.71346
# [91]	validation_0-mae:22.66575	validation_0-rmse:31.71957
# [92]	validation_0-mae:22.65386	validation_0-rmse:31.70960
# [93]	validation_0-mae:22.64898	validation_0-rmse:31.71208
# [94]	validation_0-mae:22.64774	validation_0-rmse:31.71684
# [95]	validation_0-mae:22.65691	validation_0-rmse:31.74142
# [96]	validation_0-mae:22.65982	validation_0-rmse:31.75082
# [97]	validation_0-mae:22.65402	validation_0-rmse:31.74544
# [98]	validation_0-mae:22.64609	validation_0-rmse:31.73443
# [99]	validation_0-mae:22.63754	validation_0-rmse:31.73214
# [100]	validation_0-mae:22.62704	validation_0-rmse:31.73349
# [101]	validation_0-mae:22.62026	validation_0-rmse:31.73008
# [102]	validation_0-mae:22.63132	validation_0-rmse:31.75985
# [103]	validation_0-mae:22.64116	validation_0-rmse:31.78853
# [104]	validation_0-mae:22.63419	validation_0-rmse:31.78164
# [105]	validation_0-mae:22.62738	validation_0-rmse:31.78444
# [106]	validation_0-mae:22.62035	validation_0-rmse:31.78438
# [107]	validation_0-mae:22.63236	validation_0-rmse:31.79041
# {'colsample_bytree': 0.7, 'early_stopping_rounds': 30, 'learning_rate': 0.05, 'max_depth': 3, 'max_leaves': 7, 'min_child_weight': 10, 'subsample': 0.6}

# %%
opti_para = {'colsample_bytree': 0.7, 'early_stopping_rounds': 30, 'learning_rate': 0.05, 'max_depth': 3, 'max_leaves': 7, 'min_child_weight': 10, 'subsample': 0.6}
# update model parameters
model.set_params(**opti_para)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.7, device='cuda', early_stopping_rounds=30,
#              enable_categorical=False, eval_metric=['mae', 'rmse'],
#              feature_types=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.05, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=3,
#              max_leaves=7, min_child_weight=10, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=50000,
#              n_jobs=-1, num_parallel_tree=None, random_state=None, ...)

# %% [markdown]
# xgb.cv for detailed analysis, optimal boosting rounds

# %%
matrix_data = xgb.DMatrix(X, Y)
fmodel = xgb.cv(opti_para, dtrain=matrix_data, num_boost_round=1000, nfold=10, metrics= ['rmse', 'mae'], as_pandas=True, seed=26, early_stopping_rounds=30)
fmodel.head()
# Out:
# c:\Users\dalto\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [10:26:39] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "early_stopping_rounds" } are not used.
#
#   warnings.warn(smsg, UserWarning)
#    train-rmse-mean  train-rmse-std  train-mae-mean  train-mae-std  \
# 0        39.085265        0.250495       28.870350       0.171088
# 1        38.740416        0.253495       28.574563       0.170412
# 2        38.425823        0.258385       28.300207       0.177764
# 3        38.133903        0.252631       28.052413       0.172659
# 4        37.870077        0.257447       27.819526       0.178556
#
#    test-rmse-mean  test-rmse-std  test-mae-mean  test-mae-std
# 0       39.073967       2.225423      28.914406      1.478690
# 1       38.751771       2.228502      28.630406      1.469532
# 2       38.456322       2.230410      28.376670      1.464121
# 3       38.189790       2.236892      28.149055      1.471093
# 4       37.957489       2.229744      27.935692      1.468768

# %% [markdown]
# #### opti model

# %%
# update model parameters
model.set_params(**opti_para)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.7, device='cuda', early_stopping_rounds=30,
#              enable_categorical=False, eval_metric=['mae', 'rmse'],
#              feature_types=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.05, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=3,
#              max_leaves=7, min_child_weight=10, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=50000,
#              n_jobs=-1, num_parallel_tree=None, random_state=None, ...)

# %%
model.set_params(n_estimators=75, early_stopping_rounds=None)
model.fit(xtrain, ytrain)
ypreds = model.predict(xtest)
# Out:
# c:\Users\dalto\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [15:04:59] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\context.cc:196: XGBoost is not compiled with CUDA support.
#   warnings.warn(smsg, UserWarning)

# %% [markdown]
# ##### Results DF

# %%
results_df = xtest.copy()
results_df['Name'] = train_z.loc[xtest.index, 'Name']
results_df['Season'] = train_z.loc[xtest.index, 'Season']
results_df['next_pa'] = train_z.loc[xtest.index, 'next_pa']
results_df['pred_wrc+'] = ypreds
results_df['season_plus1_wrc+'] = ytest
results_df = results_df[['Name', 'Season', 'pred_wrc+', 'season_plus1_wrc+', 'next_pa']]
results_df['miss'] = (results_df['season_plus1_wrc+'] - results_df['pred_wrc+']).abs()
results_df.head()
# Out:
#                    Name  Season   pred_wrc+  season_plus1_wrc+     next_pa  \
# 5309    steven souza jr    2017  106.802032          84.442374  417.075966
# 1504         david dahl    2020   73.901360          52.594771  346.581208
# 1142       chris owings    2019   65.679741          88.255687  179.329387
# 2421  jackie bradley jr    2018  105.968719          89.469887  467.667532
# 5175       seiya suzuki    2023  113.660652         137.796555  575.043456
#
#            miss
# 5309  22.359659
# 1504  21.306589
# 1142  22.575946
# 2421  16.498832
# 5175  24.135903

# %% [markdown]
# ##### Model Eval

# %%
xgb.plot_importance(model)
plt.show()

# %%
xgb.plot_tree(model)
plt.gcf().set_size_inches(18.5, 10.5)
plt.show()

# %% [markdown]
# #### Metrics

# %%
from sklearn.metrics import r2_score, root_mean_squared_error, mean_absolute_error

r2 = r2_score(y_true=ytest, y_pred=ypreds)
mae = mean_absolute_error(y_true=ytest, y_pred=ypreds)
rmse = root_mean_squared_error(y_true=ytest, y_pred=ypreds)

print(f"R^2: {r2} \n mse: {mae} \n rmse: {rmse}")
# Out:
# R^2: 0.3264368962585851
#  mse: 25.94588812782744
#  rmse: 35.94529778723365

# %% [markdown]
# #### 2025 Predections

# %%
next_pa = pd.read_csv('./predicted_data/pa_25.csv')
next_pa = next_pa.drop(columns=['Unnamed: 0'])

# %%
season = z_score_df[z_score_df['Season'] >= 2024].copy()
season = season.reset_index()
season = season.merge(next_pa, on='Name', how='left')
season = season.rename(columns={'avg_pred_pa':'next_pa'})
season = season.drop(columns=['index'])

# %%
season_pred = season.drop(columns=['Name', 'woba','player_id', 'pa', 
                                   'bb_percent', 'k_percent', 'woba', 'BsR', 'Def', 
                                   'Season', 'swing_percent', 'Z-Contact%', 'O-Contact%', 'Age'])

# %%
preds_2025 = model.predict(season_pred)
preds_2025 = pd.DataFrame(preds_2025)
preds_2025['Name'] = season['Name']

# %%
preds_2025.to_csv('./predicted_data/wrc_pred/reg_15_23_preds.csv')
