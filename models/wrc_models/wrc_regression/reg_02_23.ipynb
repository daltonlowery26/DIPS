# %% [markdown]
# ### xgboost model to predict mean player outcomes
# used in conjunction with nn algs to determine mean wrc for player. Three diffrent models based on available data then combinded to create an xgb predection.

# %%
import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt

os.chdir('C:/Users/dalto/OneDrive/Pictures/Documents/Projects/MLB Season Model/')

# %%
# import data
data_02_24 = pd.read_csv('./data/cleaned/data_02_24.csv')
df = data_02_24.drop(columns=['Unnamed: 0'])
df = df.dropna()

# %% [markdown]
# #### find the z_score of each stat
# weighted avg of year, std of year, 10 away from 100 is one std

# %%
def mean_year(group):
        avg = np.average(group, weights=group.index.map(lambda x: df.loc[x, 'PA']))
        return avg

# %%
# weighted std to account for low PA outlier preformances
def calculate_weighted_std(group):
    avg = np.average(group, weights=group.index.map(lambda x: df.loc[x, 'PA']))
    variance = np.average((group - avg)**2, weights=group.index.map(lambda x: df.loc[x, 'PA']))
    return np.sqrt(variance)

# %%
def z_scores(player_df, mean_df, std_df):
    # z scores for each stat and player, also creating a new df flow, add back names based on MLBAMID later
    z_scores = pd.DataFrame(index=player_df.index, columns=player_df.select_dtypes(include=[np.number]).columns)

    # scaled for each col
    for col in player_df.select_dtypes(include=[np.number]).columns:
        if col not in ['Season', 'MLBAMID']:  # not needed
            for idx in player_df.index:
                season = player_df.loc[idx, 'Season']
                value = player_df.loc[idx, col]
                mean = mean_df.loc[mean_df['Season'] == season, col].iloc[0]
                std = std_df.loc[std_df['Season'] == season, col].iloc[0]
                # scale so that 10 is 1 std away
                z_scores.loc[idx, col] = 100 + ((value - mean) / std * 10)

    z_scores['Season'] = player_df['Season']
    
    # cols to numeric
    for col in z_scores.columns:
        if col not in ['Season', 'MLBAMID']:
            z_scores[col] = pd.to_numeric(z_scores[col])
    
    # reinsert player names
    z_scores.insert(0, 'Name', player_df['Name']) 

    return z_scores

# %%
# df to store mean results
mean_values = pd.DataFrame(index=df['Season'].unique())

for col in df.select_dtypes(include=[np.number]).columns:
    if col != 'Season' and col != 'MLBAMID':  # skip meaningless numeric
        yearly_mean = df.groupby('Season')[col].apply(mean_year)
        mean_values[col] = yearly_mean

# reset and rename index
mean_values = mean_values.reset_index()
mean_values = mean_values.rename(columns={'index': 'Season'})

# sort and display
mean_values = mean_values.sort_values(by=['Season'])
mean_values.head()
# Out:
#     Season          PA        Age       BB%        K%     BABIP        wRC+  \
# 19    2002  473.684181  29.200233  0.088931  0.162881  0.294877   99.856949
# 22    2003  475.461939  29.191111  0.086575  0.159114  0.296402   99.927082
# 20    2004  477.651063  29.335336  0.087845  0.163399  0.299236   99.906874
# 14    2005  475.451649  29.259353  0.083354  0.159429  0.297611  100.116588
# 15    2006  483.988528  29.191618  0.085995  0.162801  0.303676  100.090682
#
#          BsR       Off       Def       WAR  O-Swing%  Z-Swing%  O-Contact%  \
# 19  0.221509  3.922156 -0.767819  1.888873  0.181982  0.703447    0.507012
# 22  0.141683  4.016513 -0.608826  1.909976  0.221738  0.691527    0.527634
# 20  0.255112  4.303784 -0.517574  1.945867  0.204546  0.693372    0.623672
# 14  0.277356  3.656253 -0.893002  1.858494  0.214757  0.681891    0.550610
# 15  0.168365  3.574442 -0.760455  1.862631  0.232215  0.671328    0.584224
#
#     Z-Contact%  Contact%    SwStr%      CSW%
# 19    0.860107  0.797336  0.094299  0.256508
# 22    0.882055  0.800120  0.093138  0.260791
# 20    0.855852  0.806547  0.088749  0.255794
# 14    0.886206  0.813783  0.086017  0.255201
# 15    0.889358  0.816041  0.084597  0.251676

# %%
# Create empty DataFrame to store results
std_values = pd.DataFrame(index=df['Season'].unique())

# Loop through numeric columns
for col in df.select_dtypes(include=[np.number]).columns:
    if col != 'Season' and col != 'MLBAMID':  # skip meaningless numeric
        yearly_std = df.groupby('Season')[col].apply(calculate_weighted_std)
        std_values[col] = yearly_std

std_values = std_values.reset_index()
std_values = std_values.rename(columns={'index': 'Season'})

std_values = std_values.sort_values(by=['Season'])
std_values.head()
# Out:
#     Season          PA       Age       BB%        K%     BABIP       wRC+  \
# 19    2002  184.243302  4.009692  0.037986  0.055977  0.035674  31.645660
# 22    2003  185.106060  4.078477  0.035647  0.053696  0.034696  30.915634
# 20    2004  189.820910  4.146485  0.037057  0.057978  0.036772  30.199233
# 14    2005  182.884548  4.155987  0.032447  0.054885  0.035186  28.238546
# 15    2006  184.138008  4.310582  0.035272  0.055416  0.036208  28.100105
#
#          BsR        Off        Def       WAR  O-Swing%  Z-Swing%  O-Contact%  \
# 19  3.121745  19.286650   9.129972  2.195603  0.047095  0.056035    0.108927
# 22  3.282536  17.866265   9.428022  2.134635  0.048461  0.058644    0.107443
# 20  3.575905  17.922925   9.712096  2.177108  0.051101  0.059314    0.106975
# 14  3.328612  16.513000  10.060394  1.953790  0.057376  0.059317    0.117271
# 15  3.600161  16.729148   9.906593  1.979241  0.060376  0.059520    0.112736
#
#     Z-Contact%  Contact%    SwStr%      CSW%
# 19    0.051809  0.061293  0.032167  0.028209
# 22    0.047224  0.060704  0.031931  0.027495
# 20    0.055553  0.063824  0.033339  0.030215
# 14    0.047543  0.061264  0.032130  0.027910
# 15    0.046223  0.061019  0.031551  0.028022

# %% [markdown]
# apply z scores

# %%
z_score_df = z_scores(player_df=df, mean_df=mean_values, std_df=std_values)

# %% [markdown]
# ### xgboost model

# %%
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.decomposition import PCA

# %% [markdown]
# make wrc+ value the next year

# %%
# remove 2024 to train model bc we do not know the following year
train_z = z_score_df[z_score_df['Season'] < 2024].copy()
train_z['next_wrc+'] = np.nan # empty col


for idx in train_z.index:
    # retrive name, season
    name = train_z.loc[idx, 'Name']
    season = train_z.loc[idx, 'Season']
    # full df
    next_year_noscale = df[(df['Name'] == name) & (df['Season'] == season + 1)]
    next_year_scaled = z_score_df[(z_score_df['Name'] == name) & (z_score_df['Season'] == season + 1)]

    # add to df
    if not next_year_noscale.empty:
        train_z.loc[idx, 'next_wrc+'] = next_year_noscale['wRC+'].iloc[0]
        train_z.loc[idx, 'next_pa'] = next_year_scaled['PA'].iloc[0] # need for later anaylsis

# remove rows of nas | players retired etc.
train_z = train_z.dropna(subset=['next_wrc+'])

# display
train_z.head()
# Out:
#               Name  Season         PA         Age         BB%          K%  \
# 0    brent clevlen    2007  74.826870   85.958971   74.686219  193.060161
# 1      brett hayes    2009  74.297907   90.367791   72.475999  127.859623
# 2   carlos peguero    2014  75.723755   96.257739  107.348483  147.612705
# 5  domingo santana    2014  76.161502   80.937328   92.701724  191.474452
# 8  eliezer alfonzo    2008  75.550163  100.406271   73.751790  132.428726
#
#         BABIP        wRC+         BsR        Off  ...        WAR    O-Swing%  \
# 0  107.344122   43.282571   98.653170  96.363387  ...  89.901996  138.703183
# 1  108.219882  117.931506   99.866315  98.235778  ...  91.580480  170.668602
# 2  148.436984   92.738037  100.377615  97.711317  ...  91.256604  122.457976
# 5   27.049843   35.300547  100.388715  95.262033  ...  88.346507  104.533169
# 8   56.320994   41.119256   98.386518  95.994778  ...  89.755634  150.740042
#
#      Z-Swing%  O-Contact%  Z-Contact%   Contact%      SwStr%        CSW%  \
# 0   88.950287   71.666459   22.211544  37.187201  169.893575  204.596460
# 1   80.735141   60.421763  105.381033  65.578050  147.469352  199.428878
# 2   73.452584   41.259125   91.336666  33.462464  156.578380  183.278087
# 5  117.006084   37.346862   46.681858  34.973860  163.064364  174.135337
# 8   83.057646   74.748966   56.559446  48.895200  160.671646  180.916565
#
#     next_wrc+    next_pa
# 0   40.620897  76.461476
# 1   68.663763  79.520422
# 2   92.949027  79.756145
# 5  111.757590  85.107766
# 8   19.347656  80.120523
#
# [5 rows x 21 columns]

# %% [markdown]
# intial selection of data before feature selection

# %%
train_z1 = train_z[train_z['next_pa'] > 85] # more then 250 PA in the next season
train_z1 = train_z1[train_z1['Season'] < 2024]
X = train_z1.drop(columns=['Name', 'Season','next_wrc+', 'next_pa', 'BsR', 'Def'])
Y = train_z1['next_wrc+']
xtrain, xtest, ytrain, ytest = train_test_split(X, Y, test_size=0.25, random_state=26)

# %% [markdown]
# feature selection, testing both PCA and a more intuitive approach

# %%
features_reduction = PCA(n_components=.99).fit_transform(X)

# %% [markdown]
# train test split

# %%
xtrain, xtest, ytrain, ytest = train_test_split(X, Y, test_size=0.25, random_state=26)

# %%
# Calculate correlation matrix
corr = train_z1.corr(numeric_only=True)

# next_wrc+ corr
corr_with_wrc = corr['next_wrc+'].sort_values(ascending=False)

print(corr_with_wrc)
# Out:
# next_wrc+     1.000000
# next_pa       0.478417
# Off           0.453600
# wRC+          0.374286
# WAR           0.351801
# BB%           0.290306
# PA            0.247713
# BABIP         0.088057
# Z-Swing%      0.047435
# SwStr%        0.012478
# K%            0.004955
# Season       -0.006838
# BsR          -0.020073
# Age          -0.020977
# O-Contact%   -0.045994
# Contact%     -0.059993
# Z-Contact%   -0.077314
# CSW%         -0.080204
# O-Swing%     -0.129966
# Def          -0.186977
# Name: next_wrc+, dtype: float64

# %%
model = xgb.XGBRegressor(n_jobs=-1, n_estimators=50000, device = "cuda", eval_metric = ['mae', 'rmse'])

# %% [markdown]
# ##### hyper para tuning

# %% [markdown]
# random search to narrow space into grid search

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
rnd_search_params = {
    'learning_rate': np.linspace(0.05, 0.2, 4),          
    'max_leaves': np.linspace(1, 40, 20, dtype=int),     
    'min_child_weight': np.linspace(1, 20, 10),         
    'subsample': np.linspace(0.3, 0.9, 7),               
    'colsample_bytree': np.linspace(0.4, 1, 7),          
    'early_stopping_rounds': np.linspace(10, 100, 10, dtype=int),  
    'max_depth': np.linspace(0, 40, 20, dtype=int)       
}

rnd_searcher = RandomizedSearchCV(model, rnd_search_params, random_state=26, n_iter=250, cv=5, n_jobs=-1, verbose=4)
rnd_searcher.fit(xtrain, ytrain, eval_set=[(xtest, ytest)])
print(rnd_searcher.best_params_)
# Out:
# Fitting 5 folds for each of 250 candidates, totalling 1250 fits
# [0]	validation_0-mae:29.02709	validation_0-rmse:39.24734
# [1]	validation_0-mae:28.75311	validation_0-rmse:38.93006
# [2]	validation_0-mae:28.49083	validation_0-rmse:38.62693
# [3]	validation_0-mae:28.24847	validation_0-rmse:38.33888
# [4]	validation_0-mae:28.03798	validation_0-rmse:38.09798
# [5]	validation_0-mae:27.84207	validation_0-rmse:37.87629
# [6]	validation_0-mae:27.66408	validation_0-rmse:37.66678
# [7]	validation_0-mae:27.51224	validation_0-rmse:37.48545
# [8]	validation_0-mae:27.35714	validation_0-rmse:37.30446
# [9]	validation_0-mae:27.21828	validation_0-rmse:37.12731
# [10]	validation_0-mae:27.09402	validation_0-rmse:36.98753
# [11]	validation_0-mae:26.98714	validation_0-rmse:36.86098
# [12]	validation_0-mae:26.86619	validation_0-rmse:36.72291
# [13]	validation_0-mae:26.76819	validation_0-rmse:36.60464
# [14]	validation_0-mae:26.66981	validation_0-rmse:36.48465
# [15]	validation_0-mae:26.59986	validation_0-rmse:36.39575
# [16]	validation_0-mae:26.50234	validation_0-rmse:36.28811
# c:\Users\dalto\anaconda3\Lib\site-packages\numpy\ma\core.py:2820: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,
# c:\Users\dalto\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [10:45:47] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\context.cc:196: XGBoost is not compiled with CUDA support.
#   warnings.warn(smsg, UserWarning)
# [17]	validation_0-mae:26.42098	validation_0-rmse:36.18205
# [18]	validation_0-mae:26.36312	validation_0-rmse:36.09814
# [19]	validation_0-mae:26.28960	validation_0-rmse:36.01911
# [20]	validation_0-mae:26.22004	validation_0-rmse:35.93465
# [21]	validation_0-mae:26.16531	validation_0-rmse:35.86880
# [22]	validation_0-mae:26.10831	validation_0-rmse:35.80144
# [23]	validation_0-mae:26.06995	validation_0-rmse:35.75406
# [24]	validation_0-mae:26.01778	validation_0-rmse:35.68507
# [25]	validation_0-mae:25.97984	validation_0-rmse:35.63733
# [26]	validation_0-mae:25.93081	validation_0-rmse:35.59215
# [27]	validation_0-mae:25.89214	validation_0-rmse:35.53803
# [28]	validation_0-mae:25.86099	validation_0-rmse:35.50208
# [29]	validation_0-mae:25.83239	validation_0-rmse:35.46330
# [30]	validation_0-mae:25.79475	validation_0-rmse:35.42043
# [31]	validation_0-mae:25.76538	validation_0-rmse:35.38725
# [32]	validation_0-mae:25.73346	validation_0-rmse:35.34757
# [33]	validation_0-mae:25.71224	validation_0-rmse:35.32009
# [34]	validation_0-mae:25.68907	validation_0-rmse:35.28747
# [35]	validation_0-mae:25.68208	validation_0-rmse:35.27539
# [36]	validation_0-mae:25.66345	validation_0-rmse:35.25269
# [37]	validation_0-mae:25.63967	validation_0-rmse:35.22295
# [38]	validation_0-mae:25.62246	validation_0-rmse:35.19313
# [39]	validation_0-mae:25.61073	validation_0-rmse:35.17496
# [40]	validation_0-mae:25.59707	validation_0-rmse:35.15835
# [41]	validation_0-mae:25.57896	validation_0-rmse:35.14035
# [42]	validation_0-mae:25.56033	validation_0-rmse:35.11771
# [43]	validation_0-mae:25.54528	validation_0-rmse:35.10002
# [44]	validation_0-mae:25.52548	validation_0-rmse:35.07325
# [45]	validation_0-mae:25.51198	validation_0-rmse:35.05931
# [46]	validation_0-mae:25.51292	validation_0-rmse:35.06161
# [47]	validation_0-mae:25.50454	validation_0-rmse:35.05043
# [48]	validation_0-mae:25.49382	validation_0-rmse:35.03697
# [49]	validation_0-mae:25.49364	validation_0-rmse:35.03364
# [50]	validation_0-mae:25.48092	validation_0-rmse:35.01353
# [51]	validation_0-mae:25.47196	validation_0-rmse:34.99812
# [52]	validation_0-mae:25.46822	validation_0-rmse:34.99066
# [53]	validation_0-mae:25.45583	validation_0-rmse:34.97775
# [54]	validation_0-mae:25.44215	validation_0-rmse:34.96717
# [55]	validation_0-mae:25.44098	validation_0-rmse:34.95855
# [56]	validation_0-mae:25.42516	validation_0-rmse:34.94106
# [57]	validation_0-mae:25.42134	validation_0-rmse:34.92775
# [58]	validation_0-mae:25.40770	validation_0-rmse:34.91387
# [59]	validation_0-mae:25.39999	validation_0-rmse:34.90728
# [60]	validation_0-mae:25.39819	validation_0-rmse:34.90539
# [61]	validation_0-mae:25.38866	validation_0-rmse:34.89636
# [62]	validation_0-mae:25.38144	validation_0-rmse:34.88807
# [63]	validation_0-mae:25.37340	validation_0-rmse:34.87742
# [64]	validation_0-mae:25.35832	validation_0-rmse:34.85676
# [65]	validation_0-mae:25.34906	validation_0-rmse:34.84424
# [66]	validation_0-mae:25.33207	validation_0-rmse:34.82331
# [67]	validation_0-mae:25.32497	validation_0-rmse:34.81858
# [68]	validation_0-mae:25.32905	validation_0-rmse:34.81885
# [69]	validation_0-mae:25.32464	validation_0-rmse:34.81614
# [70]	validation_0-mae:25.32570	validation_0-rmse:34.81127
# [71]	validation_0-mae:25.32359	validation_0-rmse:34.81070
# [72]	validation_0-mae:25.32500	validation_0-rmse:34.81103
# [73]	validation_0-mae:25.31968	validation_0-rmse:34.80752
# [74]	validation_0-mae:25.31600	validation_0-rmse:34.80497
# [75]	validation_0-mae:25.31663	validation_0-rmse:34.80235
# [76]	validation_0-mae:25.31723	validation_0-rmse:34.80005
# [77]	validation_0-mae:25.32251	validation_0-rmse:34.80701
# [78]	validation_0-mae:25.32197	validation_0-rmse:34.80533
# [79]	validation_0-mae:25.31337	validation_0-rmse:34.79347
# [80]	validation_0-mae:25.31149	validation_0-rmse:34.79217
# [81]	validation_0-mae:25.30586	validation_0-rmse:34.78531
# [82]	validation_0-mae:25.30558	validation_0-rmse:34.78550
# [83]	validation_0-mae:25.30052	validation_0-rmse:34.78088
# [84]	validation_0-mae:25.28862	validation_0-rmse:34.77168
# [85]	validation_0-mae:25.28548	validation_0-rmse:34.76846
# [86]	validation_0-mae:25.28505	validation_0-rmse:34.76224
# [87]	validation_0-mae:25.28947	validation_0-rmse:34.76091
# [88]	validation_0-mae:25.28634	validation_0-rmse:34.75313
# [89]	validation_0-mae:25.28501	validation_0-rmse:34.75990
# [90]	validation_0-mae:25.28314	validation_0-rmse:34.75491
# [91]	validation_0-mae:25.28797	validation_0-rmse:34.75004
# [92]	validation_0-mae:25.29074	validation_0-rmse:34.74521
# [93]	validation_0-mae:25.28721	validation_0-rmse:34.74452
# [94]	validation_0-mae:25.28330	validation_0-rmse:34.74223
# [95]	validation_0-mae:25.28429	validation_0-rmse:34.74324
# [96]	validation_0-mae:25.27927	validation_0-rmse:34.74215
# [97]	validation_0-mae:25.27688	validation_0-rmse:34.74052
# [98]	validation_0-mae:25.27809	validation_0-rmse:34.74188
# [99]	validation_0-mae:25.27595	validation_0-rmse:34.74279
# [100]	validation_0-mae:25.27039	validation_0-rmse:34.73420
# [101]	validation_0-mae:25.26833	validation_0-rmse:34.73364
# [102]	validation_0-mae:25.26322	validation_0-rmse:34.72846
# [103]	validation_0-mae:25.26061	validation_0-rmse:34.72598
# [104]	validation_0-mae:25.25224	validation_0-rmse:34.71857
# [105]	validation_0-mae:25.24783	validation_0-rmse:34.71896
# [106]	validation_0-mae:25.24167	validation_0-rmse:34.71186
# [107]	validation_0-mae:25.23728	validation_0-rmse:34.70535
# [108]	validation_0-mae:25.23716	validation_0-rmse:34.70113
# [109]	validation_0-mae:25.23503	validation_0-rmse:34.69810
# [110]	validation_0-mae:25.23257	validation_0-rmse:34.69848
# [111]	validation_0-mae:25.22724	validation_0-rmse:34.68725
# [112]	validation_0-mae:25.23255	validation_0-rmse:34.69205
# [113]	validation_0-mae:25.22829	validation_0-rmse:34.69035
# [114]	validation_0-mae:25.22702	validation_0-rmse:34.68716
# [115]	validation_0-mae:25.22225	validation_0-rmse:34.68015
# [116]	validation_0-mae:25.22718	validation_0-rmse:34.68491
# [117]	validation_0-mae:25.23320	validation_0-rmse:34.69866
# [118]	validation_0-mae:25.23769	validation_0-rmse:34.69912
# [119]	validation_0-mae:25.24178	validation_0-rmse:34.70229
# [120]	validation_0-mae:25.24584	validation_0-rmse:34.70802
# [121]	validation_0-mae:25.23968	validation_0-rmse:34.69979
# [122]	validation_0-mae:25.23334	validation_0-rmse:34.69977
# [123]	validation_0-mae:25.22919	validation_0-rmse:34.70031
# [124]	validation_0-mae:25.22397	validation_0-rmse:34.69878
# [125]	validation_0-mae:25.22105	validation_0-rmse:34.69705
# [126]	validation_0-mae:25.22176	validation_0-rmse:34.69611
# [127]	validation_0-mae:25.21724	validation_0-rmse:34.69575
# [128]	validation_0-mae:25.21683	validation_0-rmse:34.69228
# [129]	validation_0-mae:25.22234	validation_0-rmse:34.70656
# [130]	validation_0-mae:25.22157	validation_0-rmse:34.71101
# [131]	validation_0-mae:25.21906	validation_0-rmse:34.70729
# [132]	validation_0-mae:25.22623	validation_0-rmse:34.71154
# [133]	validation_0-mae:25.22917	validation_0-rmse:34.71543
# [134]	validation_0-mae:25.22683	validation_0-rmse:34.71001
# [135]	validation_0-mae:25.23038	validation_0-rmse:34.71360
# [136]	validation_0-mae:25.23031	validation_0-rmse:34.70873
# [137]	validation_0-mae:25.22168	validation_0-rmse:34.70627
# [138]	validation_0-mae:25.22666	validation_0-rmse:34.70921
# [139]	validation_0-mae:25.22581	validation_0-rmse:34.70504
# [140]	validation_0-mae:25.22740	validation_0-rmse:34.70443
# [141]	validation_0-mae:25.23201	validation_0-rmse:34.71310
# [142]	validation_0-mae:25.23960	validation_0-rmse:34.72326
# [143]	validation_0-mae:25.23766	validation_0-rmse:34.72004
# [144]	validation_0-mae:25.23255	validation_0-rmse:34.71963
# [145]	validation_0-mae:25.24174	validation_0-rmse:34.72994
# [146]	validation_0-mae:25.24276	validation_0-rmse:34.72773
# [147]	validation_0-mae:25.23424	validation_0-rmse:34.72563
# [148]	validation_0-mae:25.22807	validation_0-rmse:34.72383
# [149]	validation_0-mae:25.22264	validation_0-rmse:34.72280
# [150]	validation_0-mae:25.21638	validation_0-rmse:34.72303
# [151]	validation_0-mae:25.22110	validation_0-rmse:34.72486
# [152]	validation_0-mae:25.21758	validation_0-rmse:34.71966
# [153]	validation_0-mae:25.21927	validation_0-rmse:34.72433
# [154]	validation_0-mae:25.20698	validation_0-rmse:34.71783
# [155]	validation_0-mae:25.20538	validation_0-rmse:34.71433
# [156]	validation_0-mae:25.20733	validation_0-rmse:34.71632
# [157]	validation_0-mae:25.20349	validation_0-rmse:34.71886
# [158]	validation_0-mae:25.20384	validation_0-rmse:34.71938
# [159]	validation_0-mae:25.19146	validation_0-rmse:34.71698
# [160]	validation_0-mae:25.20225	validation_0-rmse:34.72220
# [161]	validation_0-mae:25.19892	validation_0-rmse:34.72070
# [162]	validation_0-mae:25.19790	validation_0-rmse:34.71797
# [163]	validation_0-mae:25.19556	validation_0-rmse:34.71254
# [164]	validation_0-mae:25.19318	validation_0-rmse:34.71180
# [165]	validation_0-mae:25.19314	validation_0-rmse:34.71087
# [166]	validation_0-mae:25.20004	validation_0-rmse:34.71067
# [167]	validation_0-mae:25.19978	validation_0-rmse:34.71121
# [168]	validation_0-mae:25.19660	validation_0-rmse:34.70263
# [169]	validation_0-mae:25.19873	validation_0-rmse:34.70511
# [170]	validation_0-mae:25.19978	validation_0-rmse:34.70609
# [171]	validation_0-mae:25.20632	validation_0-rmse:34.70721
# [172]	validation_0-mae:25.21048	validation_0-rmse:34.71713
# [173]	validation_0-mae:25.21498	validation_0-rmse:34.71978
# [174]	validation_0-mae:25.22294	validation_0-rmse:34.72290
# [175]	validation_0-mae:25.21890	validation_0-rmse:34.71791
# [176]	validation_0-mae:25.21905	validation_0-rmse:34.71210
# [177]	validation_0-mae:25.22095	validation_0-rmse:34.71665
# [178]	validation_0-mae:25.21954	validation_0-rmse:34.71475
# [179]	validation_0-mae:25.22283	validation_0-rmse:34.71815
# [180]	validation_0-mae:25.22131	validation_0-rmse:34.71558
# [181]	validation_0-mae:25.22314	validation_0-rmse:34.71786
# [182]	validation_0-mae:25.22611	validation_0-rmse:34.72284
# [183]	validation_0-mae:25.22832	validation_0-rmse:34.72070
# [184]	validation_0-mae:25.22775	validation_0-rmse:34.72036
# [185]	validation_0-mae:25.22812	validation_0-rmse:34.71826
# [186]	validation_0-mae:25.22764	validation_0-rmse:34.71994
# [187]	validation_0-mae:25.22622	validation_0-rmse:34.71468
# [188]	validation_0-mae:25.21986	validation_0-rmse:34.70862
# [189]	validation_0-mae:25.22250	validation_0-rmse:34.70755
# [190]	validation_0-mae:25.22440	validation_0-rmse:34.71047
# [191]	validation_0-mae:25.22074	validation_0-rmse:34.72072
# [192]	validation_0-mae:25.22522	validation_0-rmse:34.72107
# [193]	validation_0-mae:25.22285	validation_0-rmse:34.71772
# [194]	validation_0-mae:25.22127	validation_0-rmse:34.72158
# [195]	validation_0-mae:25.22191	validation_0-rmse:34.71875
# [196]	validation_0-mae:25.21456	validation_0-rmse:34.71778
# [197]	validation_0-mae:25.21592	validation_0-rmse:34.71300
# [198]	validation_0-mae:25.21612	validation_0-rmse:34.71098
# [199]	validation_0-mae:25.21773	validation_0-rmse:34.71456
# [200]	validation_0-mae:25.21723	validation_0-rmse:34.71295
# [201]	validation_0-mae:25.21981	validation_0-rmse:34.71492
# [202]	validation_0-mae:25.21882	validation_0-rmse:34.71294
# [203]	validation_0-mae:25.22077	validation_0-rmse:34.71443
# [204]	validation_0-mae:25.21809	validation_0-rmse:34.71566
# {'subsample': 0.5, 'min_child_weight': 15.777777777777779, 'max_leaves': 27, 'max_depth': 2, 'learning_rate': 0.05, 'early_stopping_rounds': 90, 'colsample_bytree': 0.8}

# %% [markdown]
# grid search

# %%
from sklearn.model_selection import GridSearchCV
grid_search_params = {
    'learning_rate': [0.05, 0.1],   
    'max_leaves': [10, 12, 14],
    'min_child_weight': [10, 11, 12],      
    'subsample': [0.4, 0.5, 0.6],           
    'colsample_bytree':[0.7, 0.8, 0.9],     
    'early_stopping_rounds':[40, 50, 60],
    'max_depth': [2, 3, 4]
}

# %%
grid_searcher = GridSearchCV(model, grid_search_params, cv=5, n_jobs=-1, verbose=4)
grid_searcher.fit(xtrain, ytrain, eval_set=[(xtest, ytest)])
print(grid_searcher.best_params_)
# Out:
# Fitting 5 folds for each of 1458 candidates, totalling 7290 fits
# [0]	validation_0-mae:29.02709	validation_0-rmse:39.24734
# [1]	validation_0-mae:28.75311	validation_0-rmse:38.93006
# [2]	validation_0-mae:28.49083	validation_0-rmse:38.62693
# [3]	validation_0-mae:28.24847	validation_0-rmse:38.33888
# [4]	validation_0-mae:28.03798	validation_0-rmse:38.09798
# [5]	validation_0-mae:27.84207	validation_0-rmse:37.87629
# [6]	validation_0-mae:27.66408	validation_0-rmse:37.66678
# [7]	validation_0-mae:27.51224	validation_0-rmse:37.48545
# [8]	validation_0-mae:27.35714	validation_0-rmse:37.30446
# [9]	validation_0-mae:27.21828	validation_0-rmse:37.12731
# [10]	validation_0-mae:27.09402	validation_0-rmse:36.98753
# [11]	validation_0-mae:26.98714	validation_0-rmse:36.86098
# [12]	validation_0-mae:26.86619	validation_0-rmse:36.72291
# [13]	validation_0-mae:26.76819	validation_0-rmse:36.60464
# [14]	validation_0-mae:26.66981	validation_0-rmse:36.48465
# [15]	validation_0-mae:26.59986	validation_0-rmse:36.39575
# [16]	validation_0-mae:26.51604	validation_0-rmse:36.30278
# [17]	validation_0-mae:26.42657	validation_0-rmse:36.19184
# [18]	validation_0-mae:26.36751	validation_0-rmse:36.10716
# [19]	validation_0-mae:26.29210	validation_0-rmse:36.02658
# [20]	validation_0-mae:26.22067	validation_0-rmse:35.94112
# [21]	validation_0-mae:26.15848	validation_0-rmse:35.85974
# [22]	validation_0-mae:26.10169	validation_0-rmse:35.79301
# [23]	validation_0-mae:26.05829	validation_0-rmse:35.74252
# [24]	validation_0-mae:26.00434	validation_0-rmse:35.67150
# [25]	validation_0-mae:25.96426	validation_0-rmse:35.62294
# [26]	validation_0-mae:25.91541	validation_0-rmse:35.57835
# [27]	validation_0-mae:25.87236	validation_0-rmse:35.52145
# [28]	validation_0-mae:25.83963	validation_0-rmse:35.48488
# [29]	validation_0-mae:25.81552	validation_0-rmse:35.45398
# [30]	validation_0-mae:25.77754	validation_0-rmse:35.41115
# [31]	validation_0-mae:25.74851	validation_0-rmse:35.37865
# c:\Users\dalto\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [11:01:28] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\context.cc:196: XGBoost is not compiled with CUDA support.
#   warnings.warn(smsg, UserWarning)
# [32]	validation_0-mae:25.72157	validation_0-rmse:35.34697
# [33]	validation_0-mae:25.70125	validation_0-rmse:35.32011
# [34]	validation_0-mae:25.67403	validation_0-rmse:35.28284
# [35]	validation_0-mae:25.66619	validation_0-rmse:35.27073
# [36]	validation_0-mae:25.64684	validation_0-rmse:35.24754
# [37]	validation_0-mae:25.62243	validation_0-rmse:35.21811
# [38]	validation_0-mae:25.60515	validation_0-rmse:35.18815
# [39]	validation_0-mae:25.59280	validation_0-rmse:35.16932
# [40]	validation_0-mae:25.57870	validation_0-rmse:35.15223
# [41]	validation_0-mae:25.56098	validation_0-rmse:35.13439
# [42]	validation_0-mae:25.54226	validation_0-rmse:35.11168
# [43]	validation_0-mae:25.53265	validation_0-rmse:35.09686
# [44]	validation_0-mae:25.51378	validation_0-rmse:35.07058
# [45]	validation_0-mae:25.50479	validation_0-rmse:35.06206
# [46]	validation_0-mae:25.50668	validation_0-rmse:35.06116
# [47]	validation_0-mae:25.49168	validation_0-rmse:35.04557
# [48]	validation_0-mae:25.47789	validation_0-rmse:35.03364
# [49]	validation_0-mae:25.47750	validation_0-rmse:35.03029
# [50]	validation_0-mae:25.46558	validation_0-rmse:35.00976
# [51]	validation_0-mae:25.45596	validation_0-rmse:34.99074
# [52]	validation_0-mae:25.45282	validation_0-rmse:34.98309
# [53]	validation_0-mae:25.44051	validation_0-rmse:34.97003
# [54]	validation_0-mae:25.42741	validation_0-rmse:34.95127
# [55]	validation_0-mae:25.42644	validation_0-rmse:34.94253
# [56]	validation_0-mae:25.40952	validation_0-rmse:34.92408
# [57]	validation_0-mae:25.40531	validation_0-rmse:34.90987
# [58]	validation_0-mae:25.39059	validation_0-rmse:34.89588
# [59]	validation_0-mae:25.38233	validation_0-rmse:34.88911
# [60]	validation_0-mae:25.37925	validation_0-rmse:34.88493
# [61]	validation_0-mae:25.37021	validation_0-rmse:34.87585
# [62]	validation_0-mae:25.36215	validation_0-rmse:34.86914
# [63]	validation_0-mae:25.35186	validation_0-rmse:34.85670
# [64]	validation_0-mae:25.33675	validation_0-rmse:34.83573
# [65]	validation_0-mae:25.33198	validation_0-rmse:34.82490
# [66]	validation_0-mae:25.31523	validation_0-rmse:34.80375
# [67]	validation_0-mae:25.30811	validation_0-rmse:34.79923
# [68]	validation_0-mae:25.30544	validation_0-rmse:34.79651
# [69]	validation_0-mae:25.30087	validation_0-rmse:34.79350
# [70]	validation_0-mae:25.30157	validation_0-rmse:34.78857
# [71]	validation_0-mae:25.30047	validation_0-rmse:34.78946
# [72]	validation_0-mae:25.30355	validation_0-rmse:34.79167
# [73]	validation_0-mae:25.29785	validation_0-rmse:34.78795
# [74]	validation_0-mae:25.29454	validation_0-rmse:34.78557
# [75]	validation_0-mae:25.29627	validation_0-rmse:34.78788
# [76]	validation_0-mae:25.29686	validation_0-rmse:34.78571
# [77]	validation_0-mae:25.30588	validation_0-rmse:34.79756
# [78]	validation_0-mae:25.30372	validation_0-rmse:34.79076
# [79]	validation_0-mae:25.29579	validation_0-rmse:34.77959
# [80]	validation_0-mae:25.29344	validation_0-rmse:34.77804
# [81]	validation_0-mae:25.28764	validation_0-rmse:34.77095
# [82]	validation_0-mae:25.28718	validation_0-rmse:34.77094
# [83]	validation_0-mae:25.28193	validation_0-rmse:34.76650
# [84]	validation_0-mae:25.26707	validation_0-rmse:34.75012
# [85]	validation_0-mae:25.26143	validation_0-rmse:34.74402
# [86]	validation_0-mae:25.26093	validation_0-rmse:34.73779
# [87]	validation_0-mae:25.26500	validation_0-rmse:34.73679
# [88]	validation_0-mae:25.26141	validation_0-rmse:34.73021
# [89]	validation_0-mae:25.26052	validation_0-rmse:34.73704
# [90]	validation_0-mae:25.25837	validation_0-rmse:34.73195
# [91]	validation_0-mae:25.25796	validation_0-rmse:34.72369
# [92]	validation_0-mae:25.26070	validation_0-rmse:34.71928
# [93]	validation_0-mae:25.25697	validation_0-rmse:34.71930
# [94]	validation_0-mae:25.25348	validation_0-rmse:34.71759
# [95]	validation_0-mae:25.25461	validation_0-rmse:34.71883
# [96]	validation_0-mae:25.25006	validation_0-rmse:34.71808
# [97]	validation_0-mae:25.24741	validation_0-rmse:34.71643
# [98]	validation_0-mae:25.25012	validation_0-rmse:34.71749
# [99]	validation_0-mae:25.24695	validation_0-rmse:34.71642
# [100]	validation_0-mae:25.23776	validation_0-rmse:34.70881
# [101]	validation_0-mae:25.23575	validation_0-rmse:34.70858
# [102]	validation_0-mae:25.22985	validation_0-rmse:34.70389
# [103]	validation_0-mae:25.22787	validation_0-rmse:34.70179
# [104]	validation_0-mae:25.21959	validation_0-rmse:34.69726
# [105]	validation_0-mae:25.21601	validation_0-rmse:34.69848
# [106]	validation_0-mae:25.21032	validation_0-rmse:34.69202
# [107]	validation_0-mae:25.20558	validation_0-rmse:34.68540
# [108]	validation_0-mae:25.20486	validation_0-rmse:34.68044
# [109]	validation_0-mae:25.19550	validation_0-rmse:34.67137
# [110]	validation_0-mae:25.19432	validation_0-rmse:34.67202
# [111]	validation_0-mae:25.19344	validation_0-rmse:34.66516
# [112]	validation_0-mae:25.19798	validation_0-rmse:34.66959
# [113]	validation_0-mae:25.19247	validation_0-rmse:34.66797
# [114]	validation_0-mae:25.19150	validation_0-rmse:34.66451
# [115]	validation_0-mae:25.18659	validation_0-rmse:34.65749
# [116]	validation_0-mae:25.19165	validation_0-rmse:34.66240
# [117]	validation_0-mae:25.19666	validation_0-rmse:34.67274
# [118]	validation_0-mae:25.20147	validation_0-rmse:34.67319
# [119]	validation_0-mae:25.20538	validation_0-rmse:34.67645
# [120]	validation_0-mae:25.20893	validation_0-rmse:34.68218
# [121]	validation_0-mae:25.20256	validation_0-rmse:34.67452
# [122]	validation_0-mae:25.19579	validation_0-rmse:34.67621
# [123]	validation_0-mae:25.19320	validation_0-rmse:34.67631
# [124]	validation_0-mae:25.18878	validation_0-rmse:34.67415
# [125]	validation_0-mae:25.18643	validation_0-rmse:34.67273
# [126]	validation_0-mae:25.18649	validation_0-rmse:34.67207
# [127]	validation_0-mae:25.18208	validation_0-rmse:34.67191
# [128]	validation_0-mae:25.18689	validation_0-rmse:34.66770
# [129]	validation_0-mae:25.19266	validation_0-rmse:34.68200
# [130]	validation_0-mae:25.19354	validation_0-rmse:34.69073
# [131]	validation_0-mae:25.19351	validation_0-rmse:34.68974
# [132]	validation_0-mae:25.20015	validation_0-rmse:34.69435
# [133]	validation_0-mae:25.20198	validation_0-rmse:34.69826
# [134]	validation_0-mae:25.19949	validation_0-rmse:34.69286
# [135]	validation_0-mae:25.20308	validation_0-rmse:34.69669
# [136]	validation_0-mae:25.20062	validation_0-rmse:34.68995
# [137]	validation_0-mae:25.19155	validation_0-rmse:34.68724
# [138]	validation_0-mae:25.19500	validation_0-rmse:34.69067
# [139]	validation_0-mae:25.19409	validation_0-rmse:34.68657
# [140]	validation_0-mae:25.19569	validation_0-rmse:34.68622
# [141]	validation_0-mae:25.19998	validation_0-rmse:34.69457
# [142]	validation_0-mae:25.19992	validation_0-rmse:34.69482
# [143]	validation_0-mae:25.19813	validation_0-rmse:34.69136
# [144]	validation_0-mae:25.19538	validation_0-rmse:34.68716
# [145]	validation_0-mae:25.20705	validation_0-rmse:34.69897
# [146]	validation_0-mae:25.20759	validation_0-rmse:34.69709
# [147]	validation_0-mae:25.19753	validation_0-rmse:34.69494
# [148]	validation_0-mae:25.19255	validation_0-rmse:34.69238
# [149]	validation_0-mae:25.18928	validation_0-rmse:34.69266
# [150]	validation_0-mae:25.18200	validation_0-rmse:34.69265
# [151]	validation_0-mae:25.18636	validation_0-rmse:34.69421
# [152]	validation_0-mae:25.18734	validation_0-rmse:34.69641
# [153]	validation_0-mae:25.18938	validation_0-rmse:34.70166
# [154]	validation_0-mae:25.17746	validation_0-rmse:34.69563
# [155]	validation_0-mae:25.17504	validation_0-rmse:34.69175
# [156]	validation_0-mae:25.17832	validation_0-rmse:34.69941
# [157]	validation_0-mae:25.17322	validation_0-rmse:34.70133
# [158]	validation_0-mae:25.17352	validation_0-rmse:34.70245
# [159]	validation_0-mae:25.16266	validation_0-rmse:34.70030
# [160]	validation_0-mae:25.18086	validation_0-rmse:34.72002
# [161]	validation_0-mae:25.18196	validation_0-rmse:34.71934
# [162]	validation_0-mae:25.17778	validation_0-rmse:34.71515
# [163]	validation_0-mae:25.17197	validation_0-rmse:34.70880
# [164]	validation_0-mae:25.16920	validation_0-rmse:34.70805
# {'colsample_bytree': 0.8, 'early_stopping_rounds': 50, 'learning_rate': 0.05, 'max_depth': 2, 'max_leaves': 10, 'min_child_weight': 12, 'subsample': 0.5}

# %%
opti_para = {'colsample_bytree': 0.7, 'early_stopping_rounds': 30, 'learning_rate': 0.05, 'max_depth': 3, 'max_leaves': 7, 'min_child_weight': 10, 'subsample': 0.6}
# update model parameters
model.set_params(**opti_para)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.7, device='cuda', early_stopping_rounds=30,
#              enable_categorical=False, eval_metric=['mae', 'rmse'],
#              feature_types=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.05, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=3,
#              max_leaves=7, min_child_weight=10, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=50000,
#              n_jobs=-1, num_parallel_tree=None, random_state=None, ...)

# %% [markdown]
# xgb.cv for detailed analysis, optimal boosting rounds

# %%
matrix_data = xgb.DMatrix(X, Y)

fmodel = xgb.cv(opti_para, dtrain=matrix_data, num_boost_round=1000, nfold=10, metrics= ['rmse', 'mae'], as_pandas=True, seed=26, early_stopping_rounds=30)
fmodel.head()
# Out:
# c:\Users\dalto\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [09:55:14] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "early_stopping_rounds" } are not used.
#
#   warnings.warn(smsg, UserWarning)
#    train-rmse-mean  train-rmse-std  train-mae-mean  train-mae-std  \
# 0        26.245661        0.086104       20.626680       0.067892
# 1        25.996312        0.081510       20.435644       0.064148
# 2        25.765863        0.080938       20.257692       0.063198
# 3        25.548442        0.082061       20.087480       0.063710
# 4        25.351474        0.081500       19.934919       0.064856
#
#    test-rmse-mean  test-rmse-std  test-mae-mean  test-mae-std
# 0       26.246080       0.790229      20.634071      0.631467
# 1       26.006632       0.782614      20.449431      0.625141
# 2       25.781601       0.768487      20.276803      0.615719
# 3       25.574311       0.755769      20.114675      0.606531
# 4       25.386280       0.741863      19.969880      0.593398

# %% [markdown]
# #### opti model

# %%
# update model parameters
model.set_params(**opti_para)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.7, device='cuda', early_stopping_rounds=30,
#              enable_categorical=False, eval_metric=['mae', 'rmse'],
#              feature_types=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.05, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=3,
#              max_leaves=7, min_child_weight=10, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=50000,
#              n_jobs=-1, num_parallel_tree=None, random_state=None, ...)

# %%
model.set_params(n_estimators=150, early_stopping_rounds=None)
model.fit(xtrain, ytrain)
ypreds = model.predict(xtest)
# Out:
# c:\Users\dalto\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [09:56:19] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\context.cc:196: XGBoost is not compiled with CUDA support.
#   warnings.warn(smsg, UserWarning)

# %% [markdown]
# ##### Results DF

# %%
results_df = xtest.copy()
results_df['Name'] = train_z.loc[xtest.index, 'Name']
results_df['Season'] = train_z.loc[xtest.index, 'Season']
results_df['next_pa'] = train_z.loc[xtest.index, 'next_pa']
results_df['pred_wrc+'] = ypreds
results_df['season_plus1_wrc+'] = ytest
results_df = results_df[['Name', 'Season', 'pred_wrc+', 'season_plus1_wrc+', 'next_pa']]
results_df['miss'] = (results_df['season_plus1_wrc+'] - results_df['pred_wrc+']).abs()
results_df.head()
# Out:
#                 Name  Season   pred_wrc+  season_plus1_wrc+     next_pa  \
# 654      jared walsh    2019   93.102028         150.261048   90.260423
# 7412    ryan ludwick    2013   96.160576          90.485256   97.063907
# 2464  kyle schwarber    2022  120.137833         119.640085  114.823849
# 999    cesar izturis    2011   81.619728          55.504495   85.089057
# 9176  starling marte    2020   98.735756         131.971256  105.082818
#
#            miss
# 654   57.159020
# 7412   5.675320
# 2464   0.497747
# 999   26.115233
# 9176  33.235500

# %% [markdown]
# ##### Model Eval

# %%
xgb.plot_importance(model)
plt.show()

# %%
xgb.plot_tree(model, num_trees=1)
plt.gcf().set_size_inches(18.5, 10.5)
plt.show()

# %% [markdown]
# #### Metrics

# %%
from sklearn.metrics import r2_score, root_mean_squared_error, mean_absolute_error

r2 = r2_score(y_true=ytest, y_pred=ypreds)
mae = mean_absolute_error(y_true=ytest, y_pred=ypreds)
rmse = root_mean_squared_error(y_true=ytest, y_pred=ypreds)

print(f"R^2: {r2} \n mse: {mae} \n rmse: {rmse}")
# Out:
# R^2: 0.24677046969685645
#  mse: 18.020760288724183
#  rmse: 23.018696933684417

# %% [markdown]
# #### 2025 Predections

# %%
season = z_score_df[z_score_df['Season'] >= 2024].copy()
season = season.reset_index()
season.drop(columns=['index'], inplace=True)
season_pred = season.drop(columns=['Name', 'Season', 'BsR', 'Def'])

# %%
preds_2025 = model.predict(season_pred)
preds_2025 = pd.DataFrame(preds_2025)
preds_2025['Name'] = season['Name']

# %%
preds_2025.to_csv('./models/wrc_models/2025_Predections/reg_02_23_preds.csv')
