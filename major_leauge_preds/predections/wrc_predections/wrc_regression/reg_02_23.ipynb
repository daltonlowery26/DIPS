# %% [markdown]
# ### xgboost model to predict mean player outcomes
# used in conjunction with nn algs to determine mean wrc for player. Three diffrent models based on available data then combinded to create an xgb predection.

# %%
import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt
import sys
function_dir = 'C:/Users/dalto/OneDrive/Pictures/Documents/Projects/MLB Season Model/tools'
sys.path.append(function_dir)

os.chdir('C:/Users/dalto/OneDrive/Pictures/Documents/Projects/MLB Season Model/')

# %%
# import data
data_02_24 = pd.read_csv('./major_leauge_preds/data/cleaned/data_02_24.csv')
df = data_02_24.drop(columns=['Unnamed: 0'])
df = df.dropna()

# %% [markdown]
# #### Normalize Data

# %%
from tools.zscore import normalize
z_score_df = normalize(df)

# %% [markdown]
# ### xgboost model

# %%
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.decomposition import PCA

# %% [markdown]
# make wrc+ value the next year

# %%
# remove 2024 to train model bc we do not know the following year
train_z = z_score_df[z_score_df['Season'] < 2024].copy()
train_z['next_wrc+'] = np.nan # empty col


for idx in train_z.index:
    # retrive name, season
    name = train_z.loc[idx, 'Name']
    season = train_z.loc[idx, 'Season']
    # full df
    next_year_noscale = df[(df['Name'] == name) & (df['Season'] == season + 1)]
    next_year_scaled = z_score_df[(z_score_df['Name'] == name) & (z_score_df['Season'] == season + 1)]

    # add to df
    if not next_year_noscale.empty:
        train_z.loc[idx, 'next_wrc+'] = next_year_noscale['wRC+'].iloc[0]
        train_z.loc[idx, 'next_pa'] = next_year_noscale['PA'].iloc[0] # need for later anaylsis

# remove rows of nas | players retired etc.
train_z = train_z.dropna(subset=['next_wrc+'])

# display
train_z.head()
# Out:
#               Name  Season         PA         Age         BB%          K%  \
# 0    brent clevlen    2007  74.826870   85.958971   74.686219  193.060161
# 1      brett hayes    2009  74.297907   90.367791   72.475999  127.859623
# 2   carlos peguero    2014  75.723755   96.257739  107.348483  147.612705
# 5  domingo santana    2014  76.161502   80.937328   92.701724  191.474452
# 8  eliezer alfonzo    2008  75.550163  100.406271   73.751790  132.428726
#
#         BABIP        wRC+         BsR        Off  ...        WAR    O-Swing%  \
# 0  107.344122   43.282571   98.653170  96.363387  ...  89.901996  138.703183
# 1  108.219882  117.931506   99.866315  98.235778  ...  91.580480  170.668602
# 2  148.436984   92.738037  100.377615  97.711317  ...  91.256604  122.457976
# 5   27.049843   35.300547  100.388715  95.262033  ...  88.346507  104.533169
# 8   56.320994   41.119256   98.386518  95.994778  ...  89.755634  150.740042
#
#      Z-Swing%  O-Contact%  Z-Contact%   Contact%      SwStr%        CSW%  \
# 0   88.950287   71.666459   22.211544  37.187201  169.893575  204.596460
# 1   80.735141   60.421763  105.381033  65.578050  147.469352  199.428878
# 2   73.452584   41.259125   91.336666  33.462464  156.578380  183.278087
# 5  117.006084   37.346862   46.681858  34.973860  163.064364  174.135337
# 8   83.057646   74.748966   56.559446  48.895200  160.671646  180.916565
#
#     next_wrc+  next_pa
# 0   40.620897     28.0
# 1   68.663763     83.0
# 2   92.949027     90.0
# 5  111.757590    187.0
# 8   19.347656    117.0
#
# [5 rows x 21 columns]

# %% [markdown]
# inject noise to next_pa
# <br>
# <small> I want to mimmic the accuracy of my projection model so that next_pa is not overweighted as a feature.

# %%
num_points = len(train_z['next_pa'])
noise = np.random.normal(loc=0, scale=75, size=num_points)  # corresponds to less than 0.8 std which is how much model misses on avg
train_z['next_pa'] = train_z['next_pa'] + noise
train_z['next_pa'] = train_z['next_pa'].clip(lower=10, upper=735)
train_z.head()
# Out:
#               Name  Season         PA         Age         BB%          K%  \
# 0    brent clevlen    2007  74.826870   85.958971   74.686219  193.060161
# 1      brett hayes    2009  74.297907   90.367791   72.475999  127.859623
# 2   carlos peguero    2014  75.723755   96.257739  107.348483  147.612705
# 5  domingo santana    2014  76.161502   80.937328   92.701724  191.474452
# 8  eliezer alfonzo    2008  75.550163  100.406271   73.751790  132.428726
#
#         BABIP        wRC+         BsR        Off  ...        WAR    O-Swing%  \
# 0  107.344122   43.282571   98.653170  96.363387  ...  89.901996  138.703183
# 1  108.219882  117.931506   99.866315  98.235778  ...  91.580480  170.668602
# 2  148.436984   92.738037  100.377615  97.711317  ...  91.256604  122.457976
# 5   27.049843   35.300547  100.388715  95.262033  ...  88.346507  104.533169
# 8   56.320994   41.119256   98.386518  95.994778  ...  89.755634  150.740042
#
#      Z-Swing%  O-Contact%  Z-Contact%   Contact%      SwStr%        CSW%  \
# 0   88.950287   71.666459   22.211544  37.187201  169.893575  204.596460
# 1   80.735141   60.421763  105.381033  65.578050  147.469352  199.428878
# 2   73.452584   41.259125   91.336666  33.462464  156.578380  183.278087
# 5  117.006084   37.346862   46.681858  34.973860  163.064364  174.135337
# 8   83.057646   74.748966   56.559446  48.895200  160.671646  180.916565
#
#     next_wrc+     next_pa
# 0   40.620897   10.000000
# 1   68.663763   10.000000
# 2   92.949027   67.442188
# 5  111.757590  182.930290
# 8   19.347656   46.521590
#
# [5 rows x 21 columns]

# %% [markdown]
# intial selection of data before feature selection

# %%
train_z = train_z[train_z['Season'] < 2024]
train_z = train_z[train_z['PA'] > 85]
X = train_z.drop(columns=['Name', 'Season','next_wrc+', 'BsR', 'Def', 'Age', 'O-Contact%', 'Z-Swing%', 'Z-Contact%', 'next_pa', 'BABIP'])
Y = train_z['next_wrc+']
xtrain, xtest, ytrain, ytest = train_test_split(X, Y, test_size=0.25, random_state=26)

# %% [markdown]
# train test split

# %%
xtrain, xtest, ytrain, ytest = train_test_split(X, Y, test_size=0.25, random_state=26)

# %%
# Calculate correlation matrix
corr = train_z.corr(numeric_only=True)

# next_wrc+ corr
corr_with_wrc = corr['next_wrc+'].sort_values(ascending=False)

print(corr_with_wrc)
# Out:
# next_wrc+     1.000000
# next_pa       0.517668
# Off           0.382569
# WAR           0.381704
# PA            0.361969
# wRC+          0.345374
# BB%           0.219980
# BABIP         0.109904
# Contact%      0.053054
# O-Contact%    0.048914
# Z-Contact%    0.034933
# Z-Swing%      0.031965
# Season        0.000939
# BsR          -0.002778
# Age          -0.017348
# SwStr%       -0.082973
# Def          -0.105743
# K%           -0.107718
# O-Swing%     -0.123050
# CSW%         -0.153511
# Name: next_wrc+, dtype: float64

# %%
model = xgb.XGBRegressor(n_jobs=-1, n_estimators=50000, device = "cuda", eval_metric = ['mae', 'rmse'])

# %% [markdown]
# ##### hyper para tuning

# %% [markdown]
# random search to narrow space into grid search

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
rnd_search_params = {
    'learning_rate': np.linspace(0.05, 0.2, 4),          
    'max_leaves': np.linspace(1, 40, 20, dtype=int),     
    'min_child_weight': np.linspace(1, 20, 10),         
    'subsample': np.linspace(0.3, 0.9, 7),               
    'colsample_bytree': np.linspace(0.4, 1, 7),          
    'early_stopping_rounds': np.linspace(10, 100, 10, dtype=int),  
    'max_depth': np.linspace(0, 40, 20, dtype=int)       
}

rnd_searcher = RandomizedSearchCV(model, rnd_search_params, random_state=26, n_iter=250, cv=5, n_jobs=-1, verbose=4)
rnd_searcher.fit(xtrain, ytrain, eval_set=[(xtest, ytest)])
print(rnd_searcher.best_params_)
# Out:
# Fitting 5 folds for each of 250 candidates, totalling 1250 fits
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[29], line 12
#       1 rnd_search_params = {
#       2     'learning_rate': np.linspace(0.05, 0.2, 4),
#       3     'max_leaves': np.linspace(1, 40, 20, dtype=int),
#    (...)
#       8     'max_depth': np.linspace(0, 40, 20, dtype=int)
#       9 }
#      11 rnd_searcher = RandomizedSearchCV(model, rnd_search_params, random_state=26, n_iter=250, cv=5, n_jobs=-1, verbose=4)
# ---> 12 rnd_searcher.fit(xtrain, ytrain, eval_set=[(xtest, ytest)])
#      13 print(rnd_searcher.best_params_)
#
# File c:\Users\dalto\anaconda3\Lib\site-packages\sklearn\base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\dalto\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:1018, in BaseSearchCV.fit(self, X, y, **params)
#    1012     results = self._format_results(
#    1013         all_candidate_params, n_splits, all_out, all_more_results
#    1014     )
#    1016     return results
# -> 1018 self._run_search(evaluate_candidates)
#    1020 # multimetric is determined here because in the case of a callable
#    1021 # self.scoring the return type is only known after calling
#    1022 first_test_score = all_out[0]["test_scores"]
#
# File c:\Users\dalto\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:1959, in RandomizedSearchCV._run_search(self, evaluate_candidates)
#    1957 def _run_search(self, evaluate_candidates):
#    1958     """Search n_iter candidates from param_distributions"""
# -> 1959     evaluate_candidates(
#    1960         ParameterSampler(
#    1961             self.param_distributions, self.n_iter, random_state=self.random_state
#    1962         )
#    1963     )
#
# File c:\Users\dalto\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:964, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     956 if self.verbose > 0:
#     957     print(
#     958         "Fitting {0} folds for each of {1} candidates,"
#     959         " totalling {2} fits".format(
#     960             n_splits, n_candidates, n_candidates * n_splits
#     961         )
#     962     )
# --> 964 out = parallel(
#     965     delayed(_fit_and_score)(
#     966         clone(base_estimator),
#     967         X,
#     968         y,
#     969         train=train,
#     970         test=test,
#     971         parameters=parameters,
#     972         split_progress=(split_idx, n_splits),
#     973         candidate_progress=(cand_idx, n_candidates),
#     974         **fit_and_score_kwargs,
#     975     )
#     976     for (cand_idx, parameters), (split_idx, (train, test)) in product(
#     977         enumerate(candidate_params),
#     978         enumerate(cv.split(X, y, **routed_params.splitter.split)),
#     979     )
#     980 )
#     982 if len(out) < 1:
#     983     raise ValueError(
#     984         "No fits were performed. "
#     985         "Was the CV iterator empty? "
#     986         "Were there no candidates?"
#     987     )
#
# File c:\Users\dalto\anaconda3\Lib\site-packages\sklearn\utils\parallel.py:74, in Parallel.__call__(self, iterable)
#      69 config = get_config()
#      70 iterable_with_config = (
#      71     (_with_config(delayed_func, config), args, kwargs)
#      72     for delayed_func, args, kwargs in iterable
#      73 )
# ---> 74 return super().__call__(iterable_with_config)
#
# File c:\Users\dalto\anaconda3\Lib\site-packages\joblib\parallel.py:2007, in Parallel.__call__(self, iterable)
#    2001 # The first item from the output is blank, but it makes the interpreter
#    2002 # progress until it enters the Try/Except block of the generator and
#    2003 # reaches the first `yield` statement. This starts the asynchronous
#    2004 # dispatch of the tasks to the workers.
#    2005 next(output)
# -> 2007 return output if self.return_generator else list(output)
#
# File c:\Users\dalto\anaconda3\Lib\site-packages\joblib\parallel.py:1650, in Parallel._get_outputs(self, iterator, pre_dispatch)
#    1647     yield
#    1649     with self._backend.retrieval_context():
# -> 1650         yield from self._retrieve()
#    1652 except GeneratorExit:
#    1653     # The generator has been garbage collected before being fully
#    1654     # consumed. This aborts the remaining tasks if possible and warn
#    1655     # the user if necessary.
#    1656     self._exception = True
#
# File c:\Users\dalto\anaconda3\Lib\site-packages\joblib\parallel.py:1762, in Parallel._retrieve(self)
#    1757 # If the next job is not ready for retrieval yet, we just wait for
#    1758 # async callbacks to progress.
#    1759 if ((len(self._jobs) == 0) or
#    1760     (self._jobs[0].get_status(
#    1761         timeout=self.timeout) == TASK_PENDING)):
# -> 1762     time.sleep(0.01)
#    1763     continue
#    1765 # We need to be careful: the job list can be filling up as
#    1766 # we empty it and Python list are not thread-safe by
#    1767 # default hence the use of the lock
#
# KeyboardInterrupt:

# %% [markdown]
# grid search

# %%
from sklearn.model_selection import GridSearchCV
grid_search_params = {
    'learning_rate': [0.05, 0.1],   
    'max_leaves': [10, 12, 14],
    'min_child_weight': [10, 11, 12],      
    'subsample': [0.4, 0.5, 0.6],           
    'colsample_bytree':[0.7, 0.8, 0.9],     
    'early_stopping_rounds':[40, 50, 60],
    'max_depth': [2, 3, 4]
}

# %%
grid_searcher = GridSearchCV(model, grid_search_params, cv=5, n_jobs=-1, verbose=4)
grid_searcher.fit(xtrain, ytrain, eval_set=[(xtest, ytest)])
print(grid_searcher.best_params_)
# Out:
# Fitting 5 folds for each of 1458 candidates, totalling 7290 fits
# [0]	validation_0-mae:29.02709	validation_0-rmse:39.24734
# [1]	validation_0-mae:28.75311	validation_0-rmse:38.93006
# [2]	validation_0-mae:28.49083	validation_0-rmse:38.62693
# [3]	validation_0-mae:28.24847	validation_0-rmse:38.33888
# [4]	validation_0-mae:28.03798	validation_0-rmse:38.09798
# [5]	validation_0-mae:27.84207	validation_0-rmse:37.87629
# [6]	validation_0-mae:27.66408	validation_0-rmse:37.66678
# [7]	validation_0-mae:27.51224	validation_0-rmse:37.48545
# [8]	validation_0-mae:27.35714	validation_0-rmse:37.30446
# [9]	validation_0-mae:27.21828	validation_0-rmse:37.12731
# [10]	validation_0-mae:27.09402	validation_0-rmse:36.98753
# [11]	validation_0-mae:26.98714	validation_0-rmse:36.86098
# [12]	validation_0-mae:26.86619	validation_0-rmse:36.72291
# [13]	validation_0-mae:26.76819	validation_0-rmse:36.60464
# [14]	validation_0-mae:26.66981	validation_0-rmse:36.48465
# [15]	validation_0-mae:26.59986	validation_0-rmse:36.39575
# [16]	validation_0-mae:26.51604	validation_0-rmse:36.30278
# [17]	validation_0-mae:26.42657	validation_0-rmse:36.19184
# [18]	validation_0-mae:26.36751	validation_0-rmse:36.10716
# [19]	validation_0-mae:26.29210	validation_0-rmse:36.02658
# [20]	validation_0-mae:26.22067	validation_0-rmse:35.94112
# [21]	validation_0-mae:26.15848	validation_0-rmse:35.85974
# [22]	validation_0-mae:26.10169	validation_0-rmse:35.79301
# [23]	validation_0-mae:26.05829	validation_0-rmse:35.74252
# [24]	validation_0-mae:26.00434	validation_0-rmse:35.67150
# [25]	validation_0-mae:25.96426	validation_0-rmse:35.62294
# [26]	validation_0-mae:25.91541	validation_0-rmse:35.57835
# [27]	validation_0-mae:25.87236	validation_0-rmse:35.52145
# [28]	validation_0-mae:25.83963	validation_0-rmse:35.48488
# [29]	validation_0-mae:25.81552	validation_0-rmse:35.45398
# [30]	validation_0-mae:25.77754	validation_0-rmse:35.41115
# [31]	validation_0-mae:25.74851	validation_0-rmse:35.37865
# c:\Users\dalto\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [11:01:28] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\context.cc:196: XGBoost is not compiled with CUDA support.
#   warnings.warn(smsg, UserWarning)
# [32]	validation_0-mae:25.72157	validation_0-rmse:35.34697
# [33]	validation_0-mae:25.70125	validation_0-rmse:35.32011
# [34]	validation_0-mae:25.67403	validation_0-rmse:35.28284
# [35]	validation_0-mae:25.66619	validation_0-rmse:35.27073
# [36]	validation_0-mae:25.64684	validation_0-rmse:35.24754
# [37]	validation_0-mae:25.62243	validation_0-rmse:35.21811
# [38]	validation_0-mae:25.60515	validation_0-rmse:35.18815
# [39]	validation_0-mae:25.59280	validation_0-rmse:35.16932
# [40]	validation_0-mae:25.57870	validation_0-rmse:35.15223
# [41]	validation_0-mae:25.56098	validation_0-rmse:35.13439
# [42]	validation_0-mae:25.54226	validation_0-rmse:35.11168
# [43]	validation_0-mae:25.53265	validation_0-rmse:35.09686
# [44]	validation_0-mae:25.51378	validation_0-rmse:35.07058
# [45]	validation_0-mae:25.50479	validation_0-rmse:35.06206
# [46]	validation_0-mae:25.50668	validation_0-rmse:35.06116
# [47]	validation_0-mae:25.49168	validation_0-rmse:35.04557
# [48]	validation_0-mae:25.47789	validation_0-rmse:35.03364
# [49]	validation_0-mae:25.47750	validation_0-rmse:35.03029
# [50]	validation_0-mae:25.46558	validation_0-rmse:35.00976
# [51]	validation_0-mae:25.45596	validation_0-rmse:34.99074
# [52]	validation_0-mae:25.45282	validation_0-rmse:34.98309
# [53]	validation_0-mae:25.44051	validation_0-rmse:34.97003
# [54]	validation_0-mae:25.42741	validation_0-rmse:34.95127
# [55]	validation_0-mae:25.42644	validation_0-rmse:34.94253
# [56]	validation_0-mae:25.40952	validation_0-rmse:34.92408
# [57]	validation_0-mae:25.40531	validation_0-rmse:34.90987
# [58]	validation_0-mae:25.39059	validation_0-rmse:34.89588
# [59]	validation_0-mae:25.38233	validation_0-rmse:34.88911
# [60]	validation_0-mae:25.37925	validation_0-rmse:34.88493
# [61]	validation_0-mae:25.37021	validation_0-rmse:34.87585
# [62]	validation_0-mae:25.36215	validation_0-rmse:34.86914
# [63]	validation_0-mae:25.35186	validation_0-rmse:34.85670
# [64]	validation_0-mae:25.33675	validation_0-rmse:34.83573
# [65]	validation_0-mae:25.33198	validation_0-rmse:34.82490
# [66]	validation_0-mae:25.31523	validation_0-rmse:34.80375
# [67]	validation_0-mae:25.30811	validation_0-rmse:34.79923
# [68]	validation_0-mae:25.30544	validation_0-rmse:34.79651
# [69]	validation_0-mae:25.30087	validation_0-rmse:34.79350
# [70]	validation_0-mae:25.30157	validation_0-rmse:34.78857
# [71]	validation_0-mae:25.30047	validation_0-rmse:34.78946
# [72]	validation_0-mae:25.30355	validation_0-rmse:34.79167
# [73]	validation_0-mae:25.29785	validation_0-rmse:34.78795
# [74]	validation_0-mae:25.29454	validation_0-rmse:34.78557
# [75]	validation_0-mae:25.29627	validation_0-rmse:34.78788
# [76]	validation_0-mae:25.29686	validation_0-rmse:34.78571
# [77]	validation_0-mae:25.30588	validation_0-rmse:34.79756
# [78]	validation_0-mae:25.30372	validation_0-rmse:34.79076
# [79]	validation_0-mae:25.29579	validation_0-rmse:34.77959
# [80]	validation_0-mae:25.29344	validation_0-rmse:34.77804
# [81]	validation_0-mae:25.28764	validation_0-rmse:34.77095
# [82]	validation_0-mae:25.28718	validation_0-rmse:34.77094
# [83]	validation_0-mae:25.28193	validation_0-rmse:34.76650
# [84]	validation_0-mae:25.26707	validation_0-rmse:34.75012
# [85]	validation_0-mae:25.26143	validation_0-rmse:34.74402
# [86]	validation_0-mae:25.26093	validation_0-rmse:34.73779
# [87]	validation_0-mae:25.26500	validation_0-rmse:34.73679
# [88]	validation_0-mae:25.26141	validation_0-rmse:34.73021
# [89]	validation_0-mae:25.26052	validation_0-rmse:34.73704
# [90]	validation_0-mae:25.25837	validation_0-rmse:34.73195
# [91]	validation_0-mae:25.25796	validation_0-rmse:34.72369
# [92]	validation_0-mae:25.26070	validation_0-rmse:34.71928
# [93]	validation_0-mae:25.25697	validation_0-rmse:34.71930
# [94]	validation_0-mae:25.25348	validation_0-rmse:34.71759
# [95]	validation_0-mae:25.25461	validation_0-rmse:34.71883
# [96]	validation_0-mae:25.25006	validation_0-rmse:34.71808
# [97]	validation_0-mae:25.24741	validation_0-rmse:34.71643
# [98]	validation_0-mae:25.25012	validation_0-rmse:34.71749
# [99]	validation_0-mae:25.24695	validation_0-rmse:34.71642
# [100]	validation_0-mae:25.23776	validation_0-rmse:34.70881
# [101]	validation_0-mae:25.23575	validation_0-rmse:34.70858
# [102]	validation_0-mae:25.22985	validation_0-rmse:34.70389
# [103]	validation_0-mae:25.22787	validation_0-rmse:34.70179
# [104]	validation_0-mae:25.21959	validation_0-rmse:34.69726
# [105]	validation_0-mae:25.21601	validation_0-rmse:34.69848
# [106]	validation_0-mae:25.21032	validation_0-rmse:34.69202
# [107]	validation_0-mae:25.20558	validation_0-rmse:34.68540
# [108]	validation_0-mae:25.20486	validation_0-rmse:34.68044
# [109]	validation_0-mae:25.19550	validation_0-rmse:34.67137
# [110]	validation_0-mae:25.19432	validation_0-rmse:34.67202
# [111]	validation_0-mae:25.19344	validation_0-rmse:34.66516
# [112]	validation_0-mae:25.19798	validation_0-rmse:34.66959
# [113]	validation_0-mae:25.19247	validation_0-rmse:34.66797
# [114]	validation_0-mae:25.19150	validation_0-rmse:34.66451
# [115]	validation_0-mae:25.18659	validation_0-rmse:34.65749
# [116]	validation_0-mae:25.19165	validation_0-rmse:34.66240
# [117]	validation_0-mae:25.19666	validation_0-rmse:34.67274
# [118]	validation_0-mae:25.20147	validation_0-rmse:34.67319
# [119]	validation_0-mae:25.20538	validation_0-rmse:34.67645
# [120]	validation_0-mae:25.20893	validation_0-rmse:34.68218
# [121]	validation_0-mae:25.20256	validation_0-rmse:34.67452
# [122]	validation_0-mae:25.19579	validation_0-rmse:34.67621
# [123]	validation_0-mae:25.19320	validation_0-rmse:34.67631
# [124]	validation_0-mae:25.18878	validation_0-rmse:34.67415
# [125]	validation_0-mae:25.18643	validation_0-rmse:34.67273
# [126]	validation_0-mae:25.18649	validation_0-rmse:34.67207
# [127]	validation_0-mae:25.18208	validation_0-rmse:34.67191
# [128]	validation_0-mae:25.18689	validation_0-rmse:34.66770
# [129]	validation_0-mae:25.19266	validation_0-rmse:34.68200
# [130]	validation_0-mae:25.19354	validation_0-rmse:34.69073
# [131]	validation_0-mae:25.19351	validation_0-rmse:34.68974
# [132]	validation_0-mae:25.20015	validation_0-rmse:34.69435
# [133]	validation_0-mae:25.20198	validation_0-rmse:34.69826
# [134]	validation_0-mae:25.19949	validation_0-rmse:34.69286
# [135]	validation_0-mae:25.20308	validation_0-rmse:34.69669
# [136]	validation_0-mae:25.20062	validation_0-rmse:34.68995
# [137]	validation_0-mae:25.19155	validation_0-rmse:34.68724
# [138]	validation_0-mae:25.19500	validation_0-rmse:34.69067
# [139]	validation_0-mae:25.19409	validation_0-rmse:34.68657
# [140]	validation_0-mae:25.19569	validation_0-rmse:34.68622
# [141]	validation_0-mae:25.19998	validation_0-rmse:34.69457
# [142]	validation_0-mae:25.19992	validation_0-rmse:34.69482
# [143]	validation_0-mae:25.19813	validation_0-rmse:34.69136
# [144]	validation_0-mae:25.19538	validation_0-rmse:34.68716
# [145]	validation_0-mae:25.20705	validation_0-rmse:34.69897
# [146]	validation_0-mae:25.20759	validation_0-rmse:34.69709
# [147]	validation_0-mae:25.19753	validation_0-rmse:34.69494
# [148]	validation_0-mae:25.19255	validation_0-rmse:34.69238
# [149]	validation_0-mae:25.18928	validation_0-rmse:34.69266
# [150]	validation_0-mae:25.18200	validation_0-rmse:34.69265
# [151]	validation_0-mae:25.18636	validation_0-rmse:34.69421
# [152]	validation_0-mae:25.18734	validation_0-rmse:34.69641
# [153]	validation_0-mae:25.18938	validation_0-rmse:34.70166
# [154]	validation_0-mae:25.17746	validation_0-rmse:34.69563
# [155]	validation_0-mae:25.17504	validation_0-rmse:34.69175
# [156]	validation_0-mae:25.17832	validation_0-rmse:34.69941
# [157]	validation_0-mae:25.17322	validation_0-rmse:34.70133
# [158]	validation_0-mae:25.17352	validation_0-rmse:34.70245
# [159]	validation_0-mae:25.16266	validation_0-rmse:34.70030
# [160]	validation_0-mae:25.18086	validation_0-rmse:34.72002
# [161]	validation_0-mae:25.18196	validation_0-rmse:34.71934
# [162]	validation_0-mae:25.17778	validation_0-rmse:34.71515
# [163]	validation_0-mae:25.17197	validation_0-rmse:34.70880
# [164]	validation_0-mae:25.16920	validation_0-rmse:34.70805
# {'colsample_bytree': 0.8, 'early_stopping_rounds': 50, 'learning_rate': 0.05, 'max_depth': 2, 'max_leaves': 10, 'min_child_weight': 12, 'subsample': 0.5}

# %%
opti_para = {'colsample_bytree': 0.7, 'early_stopping_rounds': 30, 'learning_rate': 0.05, 'max_depth': 3, 'max_leaves': 7, 'min_child_weight': 10, 'subsample': 0.6}
# update model parameters
model.set_params(**opti_para)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.7, device='cuda', early_stopping_rounds=30,
#              enable_categorical=False, eval_metric=['mae', 'rmse'],
#              feature_types=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.05, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=3,
#              max_leaves=7, min_child_weight=10, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=50000,
#              n_jobs=-1, num_parallel_tree=None, random_state=None, ...)

# %% [markdown]
# xgb.cv for detailed analysis, optimal boosting rounds

# %%
matrix_data = xgb.DMatrix(X, Y)
fmodel = xgb.cv(opti_para, dtrain=matrix_data, num_boost_round=1000, nfold=10, metrics= ['rmse', 'mae'], as_pandas=True, seed=26, early_stopping_rounds=30)
fmodel.head()
# Out:
# c:\Users\dalto\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [16:41:29] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "early_stopping_rounds" } are not used.
#
#   warnings.warn(smsg, UserWarning)
#    train-rmse-mean  train-rmse-std  train-mae-mean  train-mae-std  \
# 0        33.864973        0.138646       25.060863       0.061226
# 1        33.521518        0.136181       24.777077       0.061236
# 2        33.218446        0.130917       24.527390       0.057084
# 3        32.931555        0.128408       24.297418       0.055252
# 4        32.715466        0.129505       24.122493       0.053974
#
#    test-rmse-mean  test-rmse-std  test-mae-mean  test-mae-std
# 0       33.859209       1.195581      25.072665      0.551599
# 1       33.525157       1.194817      24.797091      0.558276
# 2       33.226520       1.194299      24.550263      0.567999
# 3       32.949234       1.187752      24.328002      0.566947
# 4       32.741364       1.182742      24.157582      0.572469

# %% [markdown]
# #### opti model

# %%
# update model parameters
model.set_params(**opti_para)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.7, device='cuda', early_stopping_rounds=30,
#              enable_categorical=False, eval_metric=['mae', 'rmse'],
#              feature_types=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.05, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=3,
#              max_leaves=7, min_child_weight=10, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=50000,
#              n_jobs=-1, num_parallel_tree=None, random_state=None, ...)

# %%
model.set_params(n_estimators=150, early_stopping_rounds=None)
model.fit(xtrain, ytrain)
ypreds = model.predict(xtest)
# Out:
# c:\Users\dalto\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [16:41:22] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\context.cc:196: XGBoost is not compiled with CUDA support.
#   warnings.warn(smsg, UserWarning)

# %% [markdown]
# ##### Results DF

# %%
results_df = xtest.copy()
results_df['Name'] = train_z.loc[xtest.index, 'Name']
results_df['Season'] = train_z.loc[xtest.index, 'Season']
results_df['next_pa'] = train_z.loc[xtest.index, 'next_pa']
results_df['pred_wrc+'] = ypreds
results_df['season_plus1_wrc+'] = ytest
results_df = results_df[['Name', 'Season', 'pred_wrc+', 'season_plus1_wrc+', 'next_pa']]
results_df['miss'] = (results_df['season_plus1_wrc+'] - results_df['pred_wrc+']).abs()
results_df.head()
# Out:
#                   Name  Season   pred_wrc+  season_plus1_wrc+     next_pa  \
# 12674      david ortiz    2012  124.701096         150.887258  735.000000
# 3231      darin erstad    2008   69.551750          51.099629   66.620969
# 12744  scooter gennett    2018  105.668785          42.760497   94.744501
# 11364      dj lemahieu    2012   76.900024          67.469567  426.200214
# 11838     hank blalock    2006   97.720833         130.196262  177.138064
#
#             miss
# 12674  26.186163
# 3231   18.452121
# 12744  62.908288
# 11364   9.430458
# 11838  32.475429

# %% [markdown]
# ##### Model Eval

# %%
xgb.plot_importance(model)
plt.show()

# %%
xgb.plot_tree(model, num_trees=1)
plt.gcf().set_size_inches(18.5, 10.5)
plt.show()

# %% [markdown]
# #### Metrics

# %%
from sklearn.metrics import r2_score, root_mean_squared_error, mean_absolute_error

r2 = r2_score(y_true=ytest, y_pred=ypreds)
mae = mean_absolute_error(y_true=ytest, y_pred=ypreds)
rmse = root_mean_squared_error(y_true=ytest, y_pred=ypreds)

print(f"R^2: {r2} \n mse: {mae} \n rmse: {rmse}")
# Out:
# R^2: 0.25850647513021974
#  mse: 22.348363867297152
#  rmse: 30.48720462788471

# %% [markdown]
# #### 2025 Predections

# %%
weighted_02_24 = pd.read_csv('./major_leauge_preds/data/multi_season/weighted_02_24.csv')
weighted_02_24 = weighted_02_24.drop(columns=['Unnamed: 0'])
weighted_02_24 = normalize(weighted_02_24)

# %%
season = z_score_df[z_score_df['Season'] >= 2024].copy()
season = season.reset_index()
season = season.drop(columns=['index'])
season = season[train_z.drop(columns=['next_wrc+', 'next_pa']).columns]

# %%
season_pred = season.drop(columns=['Name', 'Season','BsR', 'Def', 'Age', 'O-Contact%', 'Z-Swing%', 'Z-Contact%', 'BABIP'])

# %%
preds_2025 = model.predict(season_pred)
preds_2025 = pd.DataFrame(preds_2025)
preds_2025['Name'] = season['Name']

# %%
preds_2025.to_csv('./major_leauge_preds/predicted_data/wrc_pred/reg_02_23_preds.csv')
